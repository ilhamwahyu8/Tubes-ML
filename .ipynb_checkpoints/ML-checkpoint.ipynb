# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from collections import Counter
from sklearn import preprocessing

# %%
dataset = pd.read_csv('air_bnb.csv')
dataset
# Out:
#              id                                               name    host_id  \
# 0          2015   Berlin-Mitte Value! Quiet courtyard/very central       2217
# 1          2695                 Prenzlauer Berg close to Mauerpark       2986
# 2          3176                    Fabulous Flat in great Location       3718
# 3          3309                  BerlinSpot Schöneberg near KaDeWe       4108
# 4          7071                   BrightRoom with sunny greenview!      17391
# ...         ...                                                ...        ...
# 22547  29856708       Cozy Apartment right in the center of Berlin   87555909
# 22548  29857108             Altbau/ Schöneberger Kiez / Schlafsofa   67537363
# 22549  29864272   Artists loft with garden in the center of Berlin    3146923
# 22550  29866805              Room for two with private shower / WC   36961901
# 22551  29867352  Sunny, modern and cozy flat in Berlin Neukölln :)  177464875
#
#         host_name     neighbourhood_group             neighbourhood  \
# 0             Ian                   Mitte           Brunnenstr. Süd
# 1         Michael                  Pankow  Prenzlauer Berg Nordwest
# 2          Britta                  Pankow   Prenzlauer Berg Südwest
# 3            Jana  Tempelhof - Schöneberg           Schöneberg-Nord
# 4          Bright                  Pankow            Helmholtzplatz
# ...           ...                     ...                       ...
# 22547     Ulisses                   Mitte           Brunnenstr. Süd
# 22548        Jörg  Tempelhof - Schöneberg           Schöneberg-Nord
# 22549      Martin                  Pankow   Prenzlauer Berg Südwest
# 22550  Arte Luise                   Mitte            Alexanderplatz
# 22551   Sebastian                Neukölln         Schillerpromenade
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      52.534537  13.402557  Entire home/apt     60               4
# 1      52.548513  13.404553     Private room     17               2
# 2      52.534996  13.417579  Entire home/apt     90              62
# 3      52.498855  13.349065     Private room     26               5
# 4      52.543157  13.415091     Private room     42               2
# ...          ...        ...              ...    ...             ...
# 22547  52.533865  13.400731  Entire home/apt     60               2
# 22548  52.496211  13.341738      Shared room     20               1
# 22549  52.531800  13.411999  Entire home/apt     85               3
# 22550  52.520802  13.378688     Private room     99               1
# 22551  52.473762  13.424447     Private room     45               5
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                    118  2018-10-28               3.76
# 1                      6  2018-10-01               1.42
# 2                    143  2017-03-20               1.25
# 3                     25  2018-08-16               0.39
# 4                    197  2018-11-04               1.75
# ...                  ...         ...                ...
# 22547                  0         NaN                NaN
# 22548                  0         NaN                NaN
# 22549                  0         NaN                NaN
# 22550                  0         NaN                NaN
# 22551                  0         NaN                NaN
#
#        calculated_host_listings_count  availability_365
# 0                                   4               141
# 1                                   1                 0
# 2                                   1               220
# 3                                   1               297
# 4                                   1                26
# ...                               ...               ...
# 22547                               1               314
# 22548                               6                78
# 22549                               2                15
# 22550                               3                 6
# 22551                               1                21
#
# [22552 rows x 16 columns]

# %%
pd.set_option('display.max_colwidth', 1000)
atrket = pd.read_csv('atr.csv')
atrket.style.set_properties(**{'text-align': 'left'})
# Out:
# <style  type="text/css" >
#     #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row0_col0 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row0_col1 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row1_col0 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row1_col1 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row2_col0 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row2_col1 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row3_col0 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row3_col1 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row4_col0 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row4_col1 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row5_col0 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row5_col1 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row6_col0 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row6_col1 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row7_col0 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row7_col1 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row8_col0 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row8_col1 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row9_col0 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row9_col1 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row10_col0 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row10_col1 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row11_col0 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row11_col1 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row12_col0 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row12_col1 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row13_col0 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row13_col1 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row14_col0 {
#             text-align:  left;
#         }    #T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row14_col1 {
#             text-align:  left;
#         }</style><table id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Column name</th>        <th class="col_heading level0 col1" >Description</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row0_col0" class="data row0 col0" >id</td>
#                         <td id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row0_col1" class="data row0 col1" >Unique identification code for the listing</td>
#             </tr>
#             <tr>
#                         <th id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row1_col0" class="data row1 col0" >name</td>
#                         <td id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row1_col1" class="data row1 col1" >Descriptive name of the listing</td>
#             </tr>
#             <tr>
#                         <th id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row2_col0" class="data row2 col0" >host_id</td>
#                         <td id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row2_col1" class="data row2 col1" >Unique identification code for the host</td>
#             </tr>
#             <tr>
#                         <th id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row3_col0" class="data row3 col0" >host_name</td>
#                         <td id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row3_col1" class="data row3 col1" >First name of the host (privacy is respected The data is open)</td>
#             </tr>
#             <tr>
#                         <th id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row4_col0" class="data row4 col0" >neighbourhood</td>
#                         <td id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row4_col1" class="data row4 col1" >A categorical character variable that specifies the name of neighbourhood of the listing</td>
#             </tr>
#             <tr>
#                         <th id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row5_col0" class="data row5 col0" >latitude</td>
#                         <td id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row5_col1" class="data row5 col1" >A numeric variable that combining the longitude to represent the location of the listing</td>
#             </tr>
#             <tr>
#                         <th id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row6_col0" class="data row6 col0" >longtitude</td>
#                         <td id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row6_col1" class="data row6 col1" >A numeric variable that combining the latitude to represent the location of the listing</td>
#             </tr>
#             <tr>
#                         <th id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row7_col0" class="data row7 col0" >room_type</td>
#                         <td id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row7_col1" class="data row7 col1" >A categorical variable including Shared Room  Private Room or Entire Room/Apt</td>
#             </tr>
#             <tr>
#                         <th id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row8_col0" class="data row8 col0" >price</td>
#                         <td id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row8_col1" class="data row8 col1" >The price of the listing</td>
#             </tr>
#             <tr>
#                         <th id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row9_col0" class="data row9 col0" >minimum_nights</td>
#                         <td id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row9_col1" class="data row9 col1" >The minimum number of nights the host requires to book their property</td>
#             </tr>
#             <tr>
#                         <th id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row10_col0" class="data row10 col0" >number_of_reviews</td>
#                         <td id="T_39cd9412_7b2e_11ea_b2ba_0068eb7df660row10_col1" class=

# %%
print(dataset.isnull().sum())
print(dataset.info())
# Out:
# id                                   0
# name                                59
# host_id                              0
# host_name                           26
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       3908
# reviews_per_month                 3914
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22552 entries, 0 to 22551
# Data columns (total 16 columns):
# id                                22552 non-null int64
# name                              22493 non-null object
# host_id                           22552 non-null int64
# host_name                         22526 non-null object
# neighbourhood_group               22552 non-null object
# neighbourhood                     22552 non-null object
# latitude                          22552 non-null float64
# longitude                         22552 non-null float64
# room_type                         22552 non-null object
# price                             22552 non-null int64
# minimum_nights                    22552 non-null int64
# number_of_reviews                 22552 non-null int64
# last_review                       18644 non-null object
# reviews_per_month                 18638 non-null float64
# calculated_host_listings_count    22552 non-null int64
# availability_365                  22552 non-null int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 2.8+ MB
# None

# %%
idx = []
idx.extend(dataset[dataset['name'].isnull()].index.tolist())
idx.extend(dataset[dataset['host_name'].isnull()].index.tolist())
idx.extend(dataset[dataset['last_review'].isnull()].index.tolist())
idx.extend(dataset[dataset['reviews_per_month'].isnull()].index.tolist())
idx.extend(dataset[dataset['availability_365'] > 365] .index.tolist())
idx.extend(dataset[dataset['minimum_nights'] <= 0] .index.tolist())
idx.extend(dataset[dataset['price'] <= 0] .index.tolist())
idx.extend(dataset[dataset['calculated_host_listings_count'] <= 0] .index.tolist())
idx = list(dict.fromkeys(idx))
len(idx)
# Out:
# 3971

# %%
# dataset[dataset['availability_365'] <= 0]
dataset.drop_duplicates()
dataset
# Out:
#              id                                               name    host_id  \
# 0          2015   Berlin-Mitte Value! Quiet courtyard/very central       2217
# 1          2695                 Prenzlauer Berg close to Mauerpark       2986
# 2          3176                    Fabulous Flat in great Location       3718
# 3          3309                  BerlinSpot Schöneberg near KaDeWe       4108
# 4          7071                   BrightRoom with sunny greenview!      17391
# ...         ...                                                ...        ...
# 22547  29856708       Cozy Apartment right in the center of Berlin   87555909
# 22548  29857108             Altbau/ Schöneberger Kiez / Schlafsofa   67537363
# 22549  29864272   Artists loft with garden in the center of Berlin    3146923
# 22550  29866805              Room for two with private shower / WC   36961901
# 22551  29867352  Sunny, modern and cozy flat in Berlin Neukölln :)  177464875
#
#         host_name     neighbourhood_group             neighbourhood  \
# 0             Ian                   Mitte           Brunnenstr. Süd
# 1         Michael                  Pankow  Prenzlauer Berg Nordwest
# 2          Britta                  Pankow   Prenzlauer Berg Südwest
# 3            Jana  Tempelhof - Schöneberg           Schöneberg-Nord
# 4          Bright                  Pankow            Helmholtzplatz
# ...           ...                     ...                       ...
# 22547     Ulisses                   Mitte           Brunnenstr. Süd
# 22548        Jörg  Tempelhof - Schöneberg           Schöneberg-Nord
# 22549      Martin                  Pankow   Prenzlauer Berg Südwest
# 22550  Arte Luise                   Mitte            Alexanderplatz
# 22551   Sebastian                Neukölln         Schillerpromenade
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      52.534537  13.402557  Entire home/apt     60               4
# 1      52.548513  13.404553     Private room     17               2
# 2      52.534996  13.417579  Entire home/apt     90              62
# 3      52.498855  13.349065     Private room     26               5
# 4      52.543157  13.415091     Private room     42               2
# ...          ...        ...              ...    ...             ...
# 22547  52.533865  13.400731  Entire home/apt     60               2
# 22548  52.496211  13.341738      Shared room     20               1
# 22549  52.531800  13.411999  Entire home/apt     85               3
# 22550  52.520802  13.378688     Private room     99               1
# 22551  52.473762  13.424447     Private room     45               5
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                    118  2018-10-28               3.76
# 1                      6  2018-10-01               1.42
# 2                    143  2017-03-20               1.25
# 3                     25  2018-08-16               0.39
# 4                    197  2018-11-04               1.75
# ...                  ...         ...                ...
# 22547                  0         NaN                NaN
# 22548                  0         NaN                NaN
# 22549                  0         NaN                NaN
# 22550                  0         NaN                NaN
# 22551                  0         NaN                NaN
#
#        calculated_host_listings_count  availability_365
# 0                                   4               141
# 1                                   1                 0
# 2                                   1               220
# 3                                   1               297
# 4                                   1                26
# ...                               ...               ...
# 22547                               1               314
# 22548                               6                78
# 22549                               2                15
# 22550                               3                 6
# 22551                               1                21
#
# [22552 rows x 16 columns]

# %%
#delete null
print("Awal: ", len(dataset))
dataset.drop(idx, inplace = True)
print("Akhir: ", len(dataset))
print(dataset.isnull().sum())
print(dataset.info())
# Out:
# Awal:  22552
# Akhir:  18581
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18581 entries, 0 to 22536
# Data columns (total 16 columns):
# id                                18581 non-null int64
# name                              18581 non-null object
# host_id                           18581 non-null int64
# host_name                         18581 non-null object
# neighbourhood_group               18581 non-null object
# neighbourhood                     18581 non-null object
# latitude                          18581 non-null float64
# longitude                         18581 non-null float64
# room_type                         18581 non-null object
# price                             18581 non-null int64
# minimum_nights                    18581 non-null int64
# number_of_reviews                 18581 non-null int64
# last_review                       18581 non-null object
# reviews_per_month                 18581 non-null float64
# calculated_host_listings_count    18581 non-null int64
# availability_365                  18581 non-null int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 2.4+ MB
# None

# %%
#gatau ini didrop kaga seharusnya
dataset = dataset.drop(['id', 'name', 'host_id', 'host_name' ,'latitude','longitude'], axis = 1)
# dataset

# %%
import seaborn as sns
from numpy import median
ng = dataset.iloc[:,[0]]
print(Counter(ng["neighbourhood_group"]))
sns.set(style="ticks", color_codes=True)
sns.set(rc={'figure.figsize':(28,14)})
ax = sns.countplot(x=ng["neighbourhood_group"], data=ng)
# Out:
# Counter({'Friedrichshain-Kreuzberg': 4587, 'Mitte': 3820, 'Pankow': 2948, 'Neukölln': 2900, 'Tempelhof - Schöneberg': 1282, 'Charlottenburg-Wilm.': 1282, 'Lichtenberg': 529, 'Treptow - Köpenick': 477, 'Steglitz - Zehlendorf': 350, 'Reinickendorf': 199, 'Marzahn - Hellersdorf': 113, 'Spandau': 94})

# %%
print(list(dataset.columns)) 
dataset
# Out:
# ['neighbourhood_group', 'neighbourhood', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']
#             neighbourhood_group             neighbourhood        room_type  \
# 0                         Mitte           Brunnenstr. Süd  Entire home/apt
# 1                        Pankow  Prenzlauer Berg Nordwest     Private room
# 2                        Pankow   Prenzlauer Berg Südwest  Entire home/apt
# 3        Tempelhof - Schöneberg           Schöneberg-Nord     Private room
# 4                        Pankow            Helmholtzplatz     Private room
# ...                         ...                       ...              ...
# 22449               Lichtenberg           Neu Lichtenberg     Private room
# 22463        Treptow - Köpenick           Oberschöneweide  Entire home/apt
# 22475  Friedrichshain-Kreuzberg  Frankfurter Allee Süd FK     Private room
# 22508                    Pankow  Prenzlauer Berg Nordwest  Entire home/apt
# 22536                    Pankow   Prenzlauer Berg Südwest  Entire home/apt
#
#        price  minimum_nights  number_of_reviews last_review  \
# 0         60               4                118  2018-10-28
# 1         17               2                  6  2018-10-01
# 2         90              62                143  2017-03-20
# 3         26               5                 25  2018-08-16
# 4         42               2                197  2018-11-04
# ...      ...             ...                ...         ...
# 22449     25               2                  1  2018-11-04
# 22463     99               1                  5  2018-11-06
# 22475     25               1                  1  2018-11-05
# 22508     70               1                  1  2018-11-07
# 22536    150              10                  2  2018-11-07
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 0                   3.76                               4               141
# 1                   1.42                               1                 0
# 2                   1.25                               1               220
# 3                   0.39                               1               297
# 4                   1.75                               1                26
# ...                  ...                             ...               ...
# 22449               1.00                               1                32
# 22463               5.00                               2               339
# 22475               1.00                               1                 8
# 22508               1.00                               1               350
# 22536               2.00                               1                69
#
# [18581 rows x 10 columns]

# %%
bDataset = dataset.copy()
# bDataset

# %%
#start of decision tree

# %%
#prediksi Room type
#Dengan daerah, harga, minimum nights
#Kelas adalah room_type
dataset = bDataset.copy()
# idxNDS = dataset[dataset['neighbourhood_group'] != "Friedrichshain-Kreuzberg"].index.tolist()
# print(len(idxNDS))
# dataset.drop(idxNDS, inplace = True)
# X = dataset.iloc[:, [3, 4]].values
X = dataset.iloc[:, [0, 3, 4]].values
y = dataset.iloc[:, 2].values
print(len(X))
# # len(newDS)


# dataset
X
# Out:
# 18581
# array([['Mitte', 60, 4],
#        ['Pankow', 17, 2],
#        ['Pankow', 90, 62],
#        ...,
#        ['Friedrichshain-Kreuzberg', 25, 1],
#        ['Pankow', 70, 1],
#        ['Pankow', 150, 10]], dtype=object)

# %%
# from sklearn.preprocessing import Normalizer

# transformer = Normalizer() # fit does nothing.
# X = transformer.transform(X[:])
# max(X[:,0])

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder = LabelEncoder()
X[:, 0] = labelencoder.fit_transform(X[:, 0])
onehotencoder = OneHotEncoder(categorical_features = [0])
X = onehotencoder.fit_transform(X).toarray()
X
# Out:
# C:\Anaconda\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Anaconda\lib\site-packages\sklearn\preprocessing\_encoders.py:451: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)
# array([[  0.,   0.,   0., ...,   0.,  60.,   4.],
#        [  0.,   0.,   0., ...,   0.,  17.,   2.],
#        [  0.,   0.,   0., ...,   0.,  90.,  62.],
#        ...,
#        [  0.,   1.,   0., ...,   0.,  25.,   1.],
#        [  0.,   0.,   0., ...,   0.,  70.,   1.],
#        [  0.,   0.,   0., ...,   0., 150.,  10.]])

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Fitting Decision Tree Classification to the Training set
from sklearn.tree import DecisionTreeClassifier, plot_tree
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=0, splitter='best')

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(sum(cm[0] + cm[1] +cm[2]))
cm
# Out:
# 3717
# array([[1323,  436,    1],
#        [ 402, 1500,   12],
#        [   7,   29,    7]], dtype=int64)

# %%
#Accuracy CM
acc = sum(cm.diagonal()) / sum(cm[0] + cm[1] + cm[2])
print("Accuracy: ", acc)
#Precission 
PrecissionA = cm[0][0] / sum(cm[0])
print("Precission A: ", PrecissionA)
PrecissionB = cm[1][1] / sum(cm[1])
print("Precission B: ", PrecissionB)
PrecissionC = cm[2][2] / sum(cm[2])
print("Precission C: ", PrecissionC)
#Recall
recA = cm[0][0] / sum(cm[:,0])
print("Recall A: ", recA)
recB = cm[1][1] / sum(cm[:,1])
print("Recall B: ", recB)
recC = cm[2][2] / sum(cm[:,2])
print("Recall C: ", recC)
# Out:
# Accuracy:  0.7613666935700834
# Precission A:  0.7517045454545455
# Precission B:  0.7836990595611285
# Precission C:  0.16279069767441862
# Recall A:  0.7638568129330254
# Recall B:  0.7633587786259542
# Recall C:  0.35

# %%
#end of decision tree

# %%
# Fitting K-NN to the Training set
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(sum(cm[0] + cm[1] +cm[2]))
cm
# Out:
# 3717
# array([[ 195,  122, 1443],
#        [  80,   83, 1751],
#        [   4,    1,   38]], dtype=int64)

# %%
#Accuracy CM
acc = sum(cm.diagonal()) / sum(cm[0] + cm[1] + cm[2])
print("Accuracy: ", acc)
#Precission 
PrecissionA = cm[0][0] / sum(cm[0])
print("Precission A: ", PrecissionA)
PrecissionB = cm[1][1] / sum(cm[1])
print("Precission B: ", PrecissionB)
PrecissionC = cm[2][2] / sum(cm[2])
print("Precission C: ", PrecissionC)
#Recall
recA = cm[0][0] / sum(cm[:,0])
print("Recall A: ", recA)
recB = cm[1][1] / sum(cm[:,1])
print("Recall B: ", recB)
recC = cm[2][2] / sum(cm[:,2])
print("Recall C: ", recC)
# Out:
# Accuracy:  0.08501479687920366
# Precission A:  0.11079545454545454
# Precission B:  0.04336468129571578
# Precission C:  0.8837209302325582
# Recall A:  0.6989247311827957
# Recall B:  0.4029126213592233
# Recall C:  0.011757425742574257
