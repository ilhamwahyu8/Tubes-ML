# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from collections import Counter
from sklearn import preprocessing
import random as rd

# %%
dataset = pd.read_csv('air_bnb.csv')
#Load Dataset
dataset
# Out:
#              id                                               name    host_id  \
# 0          2015   Berlin-Mitte Value! Quiet courtyard/very central       2217
# 1          2695                 Prenzlauer Berg close to Mauerpark       2986
# 2          3176                    Fabulous Flat in great Location       3718
# 3          3309                  BerlinSpot Schöneberg near KaDeWe       4108
# 4          7071                   BrightRoom with sunny greenview!      17391
# ...         ...                                                ...        ...
# 22547  29856708       Cozy Apartment right in the center of Berlin   87555909
# 22548  29857108             Altbau/ Schöneberger Kiez / Schlafsofa   67537363
# 22549  29864272   Artists loft with garden in the center of Berlin    3146923
# 22550  29866805              Room for two with private shower / WC   36961901
# 22551  29867352  Sunny, modern and cozy flat in Berlin Neukölln :)  177464875
#
#         host_name     neighbourhood_group             neighbourhood  \
# 0             Ian                   Mitte           Brunnenstr. Süd
# 1         Michael                  Pankow  Prenzlauer Berg Nordwest
# 2          Britta                  Pankow   Prenzlauer Berg Südwest
# 3            Jana  Tempelhof - Schöneberg           Schöneberg-Nord
# 4          Bright                  Pankow            Helmholtzplatz
# ...           ...                     ...                       ...
# 22547     Ulisses                   Mitte           Brunnenstr. Süd
# 22548        Jörg  Tempelhof - Schöneberg           Schöneberg-Nord
# 22549      Martin                  Pankow   Prenzlauer Berg Südwest
# 22550  Arte Luise                   Mitte            Alexanderplatz
# 22551   Sebastian                Neukölln         Schillerpromenade
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      52.534537  13.402557  Entire home/apt     60               4
# 1      52.548513  13.404553     Private room     17               2
# 2      52.534996  13.417579  Entire home/apt     90              62
# 3      52.498855  13.349065     Private room     26               5
# 4      52.543157  13.415091     Private room     42               2
# ...          ...        ...              ...    ...             ...
# 22547  52.533865  13.400731  Entire home/apt     60               2
# 22548  52.496211  13.341738      Shared room     20               1
# 22549  52.531800  13.411999  Entire home/apt     85               3
# 22550  52.520802  13.378688     Private room     99               1
# 22551  52.473762  13.424447     Private room     45               5
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                    118  2018-10-28               3.76
# 1                      6  2018-10-01               1.42
# 2                    143  2017-03-20               1.25
# 3                     25  2018-08-16               0.39
# 4                    197  2018-11-04               1.75
# ...                  ...         ...                ...
# 22547                  0         NaN                NaN
# 22548                  0         NaN                NaN
# 22549                  0         NaN                NaN
# 22550                  0         NaN                NaN
# 22551                  0         NaN                NaN
#
#        calculated_host_listings_count  availability_365
# 0                                   4               141
# 1                                   1                 0
# 2                                   1               220
# 3                                   1               297
# 4                                   1                26
# ...                               ...               ...
# 22547                               1               314
# 22548                               6                78
# 22549                               2                15
# 22550                               3                 6
# 22551                               1                21
#
# [22552 rows x 16 columns]

# %%
dataset.isnull().sum()
#Mencari total dataset dengan nilai null
# Out:
# id                                   0
# name                                59
# host_id                              0
# host_name                           26
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       3908
# reviews_per_month                 3914
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %%
print(len(dataset))
dataset.drop_duplicates()
print(len(dataset))
#mencari dan drop data yang duplikat
# Out:
# 22552
# 22552

# %%
# idx = []
# idx.extend(dataset[dataset['name'].isnull()].index.tolist())
# #Mengumpulkan index dari data null atribute name
# idx.extend(dataset[dataset['host_name'].isnull()].index.tolist())
# #Mengumpulkan index dari data null atribute host_name
# idx.extend(dataset[dataset['last_review'].isnull()].index.tolist())
# #Mengumpulkan index dari data null atribute last_review
# idx.extend(dataset[dataset['reviews_per_month'].isnull()].index.tolist())
# #Mengumpulkan index dari data null atribute reviews_per_month
# idx = list(dict.fromkeys(idx))
# #Penghapusan data yang duplikat dalam list idx
# len(idx)

# %%
import seaborn as sns
from numpy import median
ng = dataset.iloc[:,[4]]
print(Counter(ng["neighbourhood_group"]))
#menghitung jumlah atribut
sns.set(style="ticks", color_codes=True)
sns.set(rc={'figure.figsize':(25,12)})
ax = sns.countplot(x=ng["neighbourhood_group"], data=ng)
#barplot informasi neighbourhood_group
# Out:
# Counter({'Friedrichshain-Kreuzberg': 5497, 'Mitte': 4631, 'Pankow': 3541, 'Neukölln': 3499, 'Charlottenburg-Wilm.': 1592, 'Tempelhof - Schöneberg': 1560, 'Lichtenberg': 688, 'Treptow - Köpenick': 595, 'Steglitz - Zehlendorf': 437, 'Reinickendorf': 247, 'Marzahn - Hellersdorf': 141, 'Spandau': 124})

# %%
import seaborn as sns
from numpy import median
ng = dataset.iloc[:,[8]]
print(Counter(ng["room_type"]))
#menghitung jumlah atribut
sns.set(style="ticks", color_codes=True)
sns.set(rc={'figure.figsize':(20,12)})
ax = sns.countplot(x=ng["room_type"], data=ng)
#Barplot informasi room_type
# Out:
# Counter({'Private room': 11534, 'Entire home/apt': 10722, 'Shared room': 296})

# %%
from matplotlib.pyplot import figure
figure(figsize=(10,2))
ng = dataset.iloc[:,[9]]
y = []
for i in range(len(ng)):
    y.append(0)
plt.scatter(ng, y, s = 100, c = 'black')
plt.title('Price')
plt.show()
#Plot data price untuk mencari data yang tidak biasa

# %%
unusualPrice = []
unusualPrice.extend(dataset[dataset['price'] > 300].index.tolist())
#memasukan index data tersebut jika diatas 300
unusualPrice.sort()
print(unusualPrice)
# Out:
# [78, 138, 746, 766, 848, 870, 1005, 1038, 1270, 1555, 1990, 2156, 2234, 2257, 2454, 2625, 2662, 2867, 2947, 3192, 3260, 3312, 3518, 4117, 4123, 4214, 4324, 4328, 4342, 4573, 4744, 5683, 6276, 6410, 6416, 6423, 6447, 6611, 6655, 6743, 7174, 7304, 7725, 7913, 8288, 8315, 8472, 8536, 8702, 8711, 8898, 8967, 9012, 9061, 9229, 9246, 9528, 9771, 10076, 10198, 11051, 11070, 11089, 11239, 11471, 11542, 11713, 12366, 12852, 13122, 13123, 13277, 13377, 13920, 14064, 14509, 14529, 14586, 14658, 14819, 15462, 15466, 15540, 15605, 15665, 15857, 16213, 16228, 16282, 16335, 16563, 16915, 16983, 16995, 17013, 17041, 17250, 17459, 17582, 17809, 18093, 18136, 18313, 18343, 18393, 18662, 18698, 18699, 18700, 18701, 18880, 18965, 19045, 19086, 19330, 19372, 19373, 19407, 19409, 19410, 19411, 19412, 19413, 19414, 19415, 19425, 19652, 19655, 19656, 19657, 19658, 19659, 19660, 19661, 19662, 19663, 19700, 19729, 20113, 20620, 20652, 20706, 20813, 21017, 21076, 21081, 21083, 21389, 21513, 21620, 21699, 21700, 21825, 21826, 21878, 21944, 22118, 22143, 22220, 22253, 22332, 22372, 22395, 22526, 22527]

# %%
dataUnusualPrice = []
for i in range (len(unusualPrice)):
    print(dataset.iloc[unusualPrice[i],:])
#melihat informasi data
# Out:
# id                                                  102882
# name                               STORAGE APARTMENT URBAN
# host_id                                              86173
# host_name                                        Sebastian
# neighbourhood_group               Friedrichshain-Kreuzberg
# neighbourhood                         Tempelhofer Vorstadt
# latitude                                           52.4888
# longitude                                           13.422
# room_type                                  Entire home/apt
# price                                                  506
# minimum_nights                                           3
# number_of_reviews                                      112
# last_review                                     2017-04-16
# reviews_per_month                                     1.24
# calculated_host_listings_count                           2
# availability_365                                         0
# Name: 78, dtype: object
# id                                                             183996
# name                              LargeTopFloor,2Terraces,Prenzl'Berg
# host_id                                                        882841
# host_name                                                    Johannes
# neighbourhood_group                                            Pankow
# neighbourhood                                          Helmholtzplatz
# latitude                                                      52.5436
# longitude                                                     13.4185
# room_type                                             Entire home/apt
# price                                                             375
# minimum_nights                                                      2
# number_of_reviews                                                  36
# last_review                                                2018-11-04
# reviews_per_month                                                0.86
# calculated_host_listings_count                                      3
# availability_365                                                  224
# Name: 138, dtype: object
# id                                                                           788811
# name                              [A] 4 bedrooms, big cook-dine-living, 2 bathrooms
# host_id                                                                     4157059
# host_name                                                                  W. Heinz
# neighbourhood_group                                                           Mitte
# neighbourhood                                                     Regierungsviertel
# latitude                                                                    52.5097
# longitude                                                                   13.4008
# room_type                                                           Entire home/apt
# price                                                                           455
# minimum_nights                                                                    2
# number_of_reviews                                                                72
# last_review                                                              2018-10-10
# reviews_per_month                                                              1.01
# calculated_host_listings_count                                                    1
# availability_365                                                                264
# Name: 746, dtype: object
# id                                                810056
# name                              20m2 of relaxation ***
# host_id                                          4259960
# host_name                                      Sébastien
# neighbourhood_group                               Pankow
# neighbourhood                             Helmholtzplatz
# latitude                                         52.5401
# longitude                                        13.4219
# room_type                                   Private room
# price                                               2228
# minimum_nights                                         1
# number_of_reviews                                     53
# last_review                                   2018-01-15
# reviews_per_month                                   0.74
# calculated_host_listings_count                         4
# availability_365                                       0
# Name: 766, dtype: object
# id                                                             885925
# name                              LOFT- 8 minutes from train station!
# host_id                                                       4074700
# host_name                                                     Philipp
# neighbourhood_group                                             Mitte
# neighbourhood                                         Wedding Zentrum
# latitude                                                      52.5471
# longitude                                                     13.3709
# room_type                                             Entire home/apt
# price                                                             650
# minimum_nights                                                      1
# number_of_reviews                                                  38
# last_review                                                2017-11-20
# reviews_per_month                                                0.55
# calculated_host_listings_count                                      1
# availability_365                                                  337
# Name: 848, dtype: object
# id                                                                          913379
# name                              Stunning Architect's Apartment centrally located
# host_id                                                                    5317830
# host_name                                                                  Yasmine
# neighbourhood_group                                           Charlottenburg-Wilm.
# neighbourhood                                                   Wiesbadener Straße
# latitude                                                                   52.4722
# longitude                                                                  13.3099
# room_type                                                          Entire home/apt
# price                                                                          329
# minimum_nights                                                                   2
# number_of_reviews                                                               14
# last_review                                                             2018-09-22
# reviews_per_month                                                             0.22
# calculated_host_listings_count                                                   2
# availability_365                                                               364
# Name: 870, dtype: object
# id                                                      1125675
# name                              Kreuzberg Private Double Room
# host_id                                                 5339703
# host_name                                                Tobias
# neighbourhood_group                    Friedrichshain-Kreuzberg
# neighbourhood                             nördliche Luisenstadt
# latitude                                                52.5024
# longitude                                               13.4292
# room_type                                          Private room
# price                                                       350
# minimum_nights                                                3
# number_of_reviews                                            29
# last_review                                          2018-11-03
# reviews_per_month                                          2.33
# calculated_host_listings_count                                1
# availability_365                                            269
# Name: 1005, dtype: object
# id                                                           1168787
# name                              Large Penthouse with stunning view
# host_id                                                       333520
# host_name                                                        Ben
# neighbourhood_group                                           Pankow
# neighbourhood                                    Prenzlauer Berg Süd
# latitude                                                     52.5317
# longitude                                                    13.4333
# room_type                                            Entire home/apt
# price                                                            350
# minimum_nights                                                     7
# number_of_reviews                                                  9
# last_review                                               2017-08-21
# reviews_per_month                                               0.14
# calculated_host_listings_count                                     1
# availability_365                                                 320
# Name: 1038, dtype: object
# id                                                                          1525270
# name                              Voll ausgestattetes Dachloft mit Blick über Be...
# host_id                                                                     8138034
# host_name                                                                  Matthias
# neighbourhood_group                                        Friedrichshain-Kreuzberg
# neighbourhood                                                Frankfurter Allee Nord
# latitude                                                                    52.5158
# longitude                                                                    13.464
# room_type                                                           Entire home/apt
# price                                                                           580
# minimum_nights                                                                    3
# number_of_reviews                                                                 0
# last_review                                                                     NaN
# reviews_per_month                                                               NaN
# calculated_host_listings_count                                                    1
# availability_365                                                                174
# Name: 1270, dtype: object
# id                                                                        2019132
# name                              Villa am Berliner Stadtrand für bis zu 25 Gäste
# host_id                                                                  10287456
# host_name                                                                    Jens
# neighbourhood_group                                            Treptow - Köpenick
# neighbourhood                                              Rahnsdorf/Hessenwinkel
# latitude                                                                  52.4558
# longitude                                                                 13.7214
# room_type                                                         Entire home/apt
# price                                                                         390
# minimum_nights                                                                  1
# number_of_reviews                                                              40
# last_review                                                            2018-08-30
# reviews_per_month                                                             0.7
# calculated_host_listings_count                                                  2
# availability_365                                                              295
# Name: 1555, dtype: object
# id                                                                          2860420
# name                              250 qm penthouse with roof terrace for photoshoot
# host_id                                                                    14623546
# host_name                                                                  Jean Luc
# neighbourhood_group                                        Friedrichshain-Kreuzberg
# neighbourhood                                                  Tempelhofer Vorstadt
# latitude                                                                    52.4935
# longitude                                                                   13.4205
# room_type                                                           Entire home/apt
# price                                                                          2500
# minimum_nights                                                                    1
# number_of_reviews                                                                19
# last_review                                                              2016-04-13
# reviews_per_month                                                              0.35
# calculated_host_listings_count                                                    1
# availability_365                                                                 89
# Name: 1990, dtype: object
# id                                              3270111
# name                              Outstanding luxury...
# host_id                                         9038479
# host_name                                        Stefan
# neighbourhood_group                              Pankow
# neighbourhood                       Prenzlauer Berg Süd
# latitude                                         52.535
# longitude                                       13.4338
# room_type                               Entire home/apt
# price                                               580
# minimum_nights                                        3
# number_of_reviews                                    45
# last_review                                  2018-10-14
# reviews_per_month                                  0.85
# calculated_host_listings_count                        1
# availability_365                                    352
# Name: 2156, dtype: object
# id                                                          3427815
# name                              Loft over the rooftops of Berlin!
# host_id                                                    17189352
# host_name                                                   Alberto
# neighbourhood_group                                          Pankow
# neighbourhood                              Prenzlauer Berg Nordwest
# latitude                                                    52.5521
# longitude                                                   13.4121
# room_type                                           Entire home/apt
# price                                                           400
# minimum_nights                                                    2
# number_of_reviews                                                53
# last_review                                              2018-10-14
# reviews_per_month                                              1.06
# calculated_host_listings_count                                    2
# availability_365                                                333
# Name: 2234, dtype: object
# id                                                              3475556
# name                              5 Rooms LUXURIOUS Apt - Centre Berlin
# host_id                                                        17463667
# host_name                                                         Andre
# neighbourhood_group                                               Mitte
# neighbourhood                                            Alexanderplatz
# latitude                                                        52.5113
# longitude                                                       13.4187
# room_type                                               Entire home/apt
# price                                                               450
# minimum_nights                                                        3
# number_of_reviews                                                    44
# last_review                                                  2018-09-21
# reviews_per_month                                                  0.86
# calculated_host_listings_count                                        1
# availability_365                                                     88
# Name: 2257, dtype: object
# id                                                                 3740368
# name                              Enjoy the summer in Berlin/Neukölln Loft
# host_id                                                           13453410
# host_name                                    Sebastian, Bene, Julia & Mona
# neighbourhood_group                                               Neukölln
# neighbourhood                                     Neuköllner Mitte/Zentrum
# latitude                                                            52.464
# longitude                                                          13.4437
# room_type                                                  Entire home/apt
# price                                                                  320
# minimum_nights                                                           3
# number_of_reviews                                                        1
# last_review                                                     2017-01-01
# reviews_per_month                                                     0.04
# calculated_host_listings_count                                           2
# availability_365                                                       276
# Name: 2454, dtype: object
# id                                                        3969577
# name                              600 qm Loft auf Insel in Berlin
# host_id                                                  20572681
# host_name                                                 Hartwig
# neighbourhood_group                          Charlottenburg-Wilm.
# neighbourhood                                 Charlottenburg Nord
# latitude                                                  52.5306
# longitude                                                 13.2873
# room_type                                         Entire home/apt
# price                                                         650
# minimum_nights                                                  2
# number_of_reviews                                               2
# last_review                                            2014-12-08
# reviews_per_month                                            0.04
# calculated_host_listings_count                                  1
# availability_365                                              363
# Name: 2625, dtype: object
# id                                                            4018296
# name                              Studio, Loft, Atelier for Shootings
# host_id                                                       5980826
# host_name                                                   Christian
# neighbourhood_group                                             Mitte
# neighbourhood                                       Regierungsviertel
# latitude                                                      52.5094
# longitude                                                     13.3969
# room_type                                             Entire home/apt
# price                                                             450
# minimum_nights                                                      1
# number_of_reviews                                                   7
# last_review                                                2018-10-02
# reviews_per_month                                                0.14
# calculated_host_listings_count                                      1
# availability_365                                                  365
# Name: 2662, dtype: object
# id                                                           4348859
# name                              ROMANTIC, GORGEOUS in PRENZELMITTE
# host_id                                                     22574198
# host_name                                                Magda - Eka
# neighbourhood_group                                           Pankow
# neighbourhood                                         Helmholtzplatz
# latitude                                                     52.5451
# longitude                                                    13.4195
# room_type                                            Entire home/apt
# price                                                            525
# minimum_nights                                                     3
# number_of_reviews                                                103
# last_review                                               2018-07-31
# reviews_per_month                                               2.41
# calculated_host_listings_count                                     1
# availability_365                                                  90
# Name: 2867, dtype: object
# id                                                            4467613
# name                              Luxury Mitte Rooftop w SunnyTerrace
# host_id                                                      22755563
# host_name                                                      Marcin
# neighbourhood_group                                             Mitte
# neighbourhood                                         Brunnenstr. Süd
# latitude                                                      52.5342
# longitude                                                      13.391
# room_type                                             Entire home/apt
# price                                                             380
# minimum_nights                                                      3
# number_of_reviews                                                  26
# last_review                                                2017-01-02
# reviews_per_month                                                0.53
# calculated_host_listings_count                                      1
# availability_365                                                  252
# Name: 2947, dtype: object
# id                                                       4819610
# name                              160sqm loft overlooking Berlin
# host_id                                                 24820271
# host_name                                               Matthias
# neighbourhood_group                                     Neukölln
# neighbourhood                           Neuköllner Mitte/Zentrum
# latitude                                                 52.4693
# longitude                                                13.4377
# room_type                                        Entire home/apt
# price                                                        400
# minimum_nights                                                 3
# number_of_reviews                                              3
# last_review                                           2017-01-02
# reviews_per_month                                           0.06
# calculated_host_listings_count                                 1
# availability_365                                               0
# Name: 3192, dtype: object
# id                                                         4901321
# name                              Flat in Prenzlauerberg for rent
# host_id                                                   25229702
# host_name                                                       L.
# neighbourhood_group                                         Pankow
# neighbourhood                                  Prenzlauer Berg Süd
# latitude                                                   52.5304
# longitude                                                  13.4269
# room_type                                          Entire home/apt
# price                                                          500
# minimum_nights                                                   1
# number_of_reviews                                                0
# last_review                                                    NaN
# reviews_per_month                                              NaN
# calculated_host_listings_count                                   1
# availability_365                                                 0
# Name: 3260, dtype: object
# id                                                                          4999999
# name                              Luxury loft: private or business trip/photoshoots
# host_id                                                                    24493536
# host_name                                                                     Julie
# neighbourhood_group                                        Friedrichshain-Kreuzberg
# neighbourhood                                                 nördliche Luisenstadt
# latitude                                                                    52.4994
# longitude                                                                   13.4253
# room_type                                                           Entire home/apt
# price                                                                           550
# minimum_nights                                                                    3
# number_of_reviews                                                                52
# last_review                                                              2018-07-14
# reviews_per_month                                                              1.19
# calculated_host_listings_count                                                    1
# availability_365                                                                 83
# Name: 3312, dtype: object
# id                                                            5335939
# name                              atelier für film-und photoshootings
# host_id                                                      27651739
# host_name                                                      Wiesje
# neighbourhood_group                              Charlottenburg-Wilm.
# neighbourhood                                              Kantstraße
# latitude                                                      52.5068
# longitude                                                     13.3204
# room_type                                                Private room
# price                                                             550
# minimum_nights                                                      1
# number_of_reviews                                                   0
# last_review                                                       NaN
# reviews_per_month                                                 NaN
# calculated_host_listings_count                                      1
# availability_365                                                  364
# Name: 3518, dtype: object
# id                                                6408850
# name                              12 m2 of relaxation ***
# host_id                                           4259960
# host_name                                       Sébastien
# neighbourhood_group                                Pankow
# neighbourhood                              Helmholtzplatz
# latitude                                          52.5404
# longitude                                          13.423
# room_type                                    Private room
# price                                                2225
# minimum_nights                                          1
# number_of_reviews                                      45
# last_review                                    2016-07-07
# reviews_per_month                                    1.07
# calculated_host_listings_count                          4
# availability_365                                       28
# Name: 4117, dtype: object
# id                                                    6416882
# name                              2 Room Appartment in Berlin
# host_id                                              33474420
# host_name                                               Peter
# neighbourhood_group                                    Pankow
# neighbourhood                                  Pankow Zentrum
# latitude                                              52.5833
# longitude                                             13.4235
# room_type                                     Entire home/apt
# price                                                     800
# minimum_nights                                              1
# number_of_reviews                                           0
# last_review                                               NaN
# reviews_per_month                                         NaN
# calculated_host_listings_count                              1
# availability_365                                            0
# Name: 4123, dtype: object
# id                                                     6558544
# name                              Beautiful flat in the center
# host_id                                               34299847
# host_name                                                David
# neighbourhood_group                     Tempelhof - Schöneberg
# neighbourhood                                  Schöneberg-Nord
# latitude                                               52.5008
# longitude                                              13.3405
# room_type                                      Entire home/apt
# price                                                      399
# minimum_nights                                               1
# number_of_reviews                                            0
# last_review                                                NaN
# reviews_per_month                                          NaN
# calculated_host_listings_count                               1
# availability_365                                             0
# Name: 4214, dtype: object
# id                                                 6680092
# name                              Olympiastadium only 1 km
# host_id                                           34966170
# host_name                                          Yannick
# neighbourhood_group                   Charlottenburg-Wilm.
# neighbourhood                                      Westend
# latitude                                           52.5178
# longitude                                          13.2555
# room_type                                  Entire home/apt
# price                                                  500
# minimum_nights                                           1
# number_of_reviews                                        0
# last_review                                            NaN
# reviews_per_month                                      NaN
# calculated_host_listings_count                           1
# availability_365                                       364
# Name: 4324, dtype: object
# id                                                          6685846
# name                              Large Penthouse in Charlottenburg
# host_id                                                    15898885
# host_name                                                    Jeremy
# neighbourhood_group                            Charlottenburg-Wilm.
# neighbourhood                                       Neue Kantstraße
# latitude                                                    52.5078
# longitude                                                   13.2959
# room_type                                           Entire home/apt
# price                                                           600
# minimum_nights                                                    1
# number_of_reviews                                                 0
# last_review                                                     NaN
# reviews_per_month                                               NaN
# calculated_host_listings_count                                    1
# availability_365                                                  0
# Name: 4328, dtype: object
# id                                                           6701135
# name                              Charming apartment (3min to metro)
# host_id                                                     34970078
# host_name                                                      Nanna
# neighbourhood_group                            Steglitz - Zehlendorf
# neighbourhood                                             Schloßstr.
# latitude                                                     52.4602
# longitude                                                    13.3198
# room_type                                            Entire home/apt
# price                                                            500
# minimum_nights                                                     7
# number_of_reviews                                                  0
# last_review                                                      NaN
# reviews_per_month                                                NaN
# calculated_host_listings_count                                     1
# availability_365                                                   0
# Name: 4342, dtype: object
# id                                                                   7024131
# name                              Gemütliches Zimmer absolut zentral gelegen
# host_id                                                             12318581
# host_name                                                               Iris
# neighbourhood_group                                                   Pankow
# neighbourhood                                                 Helmholtzplatz
# latitude                                                             52.5428
# longitude                                                            13.4229
# room_type                                                       Private room
# price                                                                   4240
# minimum_nights                                                             7
# number_of_reviews                                                         16
# last_review                                                       2018-08-10
# reviews_per_month                                                       0.41
# calculated_host_listings_count                                             1
# availability_365                                                           0
# Name: 4573, dtype: object
# id                                       7239371
# name                                   Night ***
# host_id                                  4259960
# host_name                              Sébastien
# neighbourhood_group                       Pankow
# neighbourhood                     Helmholtzplatz
# latitude                                 52.5395
# longitude                                13.4236
# room_type                           Private room
# price                                       2225
# minimum_nights                                 1
# number_of_reviews                             23
# last_review                           2016-06-06
# reviews_per_month                           0.57
# calculated_host_listings_count                 4
# availability_365                               0
# Name: 4744, dtype: object
# id                                                            8117216
# name                              180 sqm Luxury Penthouse w/ Rooftop
# host_id                                                       2036581
# host_name                                                      Verena
# neighbourhood_group                                             Mitte
# neighbourhood                                         Brunnenstr. Süd
# latitude                                                      52.5391
# longitude                                                     13.4017
# room_type                                             Entire home/apt
# price                                                             595
# minimum_nights                                                      3
# number_of_reviews                                                  40
# last_review                                                2018-09-20
# reviews_per_month                                                1.07
# calculated_host_listings_count                                      1
# availability_365                                                  364
# Name: 5683, dtype: object
# id                                                       9057083
# name                              Wintertörns Berlin-Rummelsburg
# host_id                                                 28605829
# host_name                                           Kuhnle-Tours
# neighbourhood_group                                  Lichtenberg
# neighbourhood                                Rummelsburger Bucht
# latitude                                                 52.4907
# longitude                                                13.4882
# room_type                                        Entire home/apt
# price                                                        302
# minimum_nights                                                 2
# number_of_reviews                                              0
# last_review                                                  NaN
# reviews_per_month                                            NaN
# calculated_host_listings_count                                 3
# availability_365                                               0
# Name: 6276, dtype: object
# id                                                           9268629
# name                              Great LEGAL Flat for 10! 5BR 3Bath
# host_id                                                       102461
# host_name                                                      Trudy
# neighbourhood_group                                         Neukölln
# neighbourhood                                      Schillerpromenade
# latitude                                                     52.4848
# longitude                                                    13.4237
# room_type                                            Entire home/apt
# price                                                            359
# minimum_nights                                                     3
# number_of_reviews                                                182
# last_review                                               2018-10-25
# reviews_per_month                                               5.98
# calculated_host_listings_count                                     9
# availability_365                                                  85
# Name: 6410, dtype: object
# id                                                             9273023
# name                              Huge LEGAL Central Design Apartement
# host_id                                                       18183098
# host_name                                                 Andre Marcel
# neighbourhood_group                           Friedrichshain-Kreuzberg
# neighbourhood                                 Frankfurter Allee Süd FK
# latitude                                                       52.5058
# longitude                                                      13.4698
# room_type                                              Entire home/apt
# price                                                              349
# minimum_nights                                                       3
# number_of_reviews                                                   45
# last_review                                                 2018-10-26
# reviews_per_month                                                 1.25
# calculated_host_listings_count                                       1
# availability_365                                                   304
# Name: 6416, dtype: object
# id                                                                          9287838
# name                              [R6] 6 rooms, 4 baths, at Park Ex-Airport, subway
# host_id                                                                      909226
# host_name                                                                    Werner
# neighbourhood_group                                          Tempelhof - Schöneberg
# neighbourhood                                                             Tempelhof
# latitude                                                                    52.4672
# longitude                                                                    13.391
# room_type                                                           Entire home/apt
# price                                                                           360
# minimum_nights                                                                    2
# number_of_reviews                                                                55
# last_review                                                              2018-10-28
# reviews_per_month                                                              1.52
# calculated_host_listings_count                                                    9
# availability_365                                                                293
# Name: 6423, dtype: object
# id                                                            9340163
# name                              Spacious Apt in the heart of Berlin
# host_id                                                      15895750
# host_name                                                      Marcel
# neighbourhood_group                                             Mitte
# neighbourhood                                          Alexanderplatz
# latitude                                                      52.5251
# longitude                                                     13.4067
# room_type                                             Entire home/apt
# price                                                             390
# minimum_nights                                                      1
# number_of_reviews                                                   0
# last_review                                                       NaN
# reviews_per_month                                                 NaN
# calculated_host_listings_count                                      1
# availability_365                                                    0
# Name: 6447, dtype: object
# id                                                     9584066
# name                              Wonderful historic townhouse
# host_id                                               15917612
# host_name                                             Johannes
# neighbourhood_group                       Charlottenburg-Wilm.
# neighbourhood                                      Heerstrasse
# latitude                                               52.5235
# longitude                                              13.2385
# room_type                                      Entire home/apt
# price                                                      350
# minimum_nights                                               4
# number_of_reviews                                            3
# last_review                                         2018-08-06
# reviews_per_month                                          0.2
# calculated_host_listings_count                               1
# availability_365                                            67
# Name: 6611, dtype: object
# id                                                         9651871
# name                              Über den Dächern Berlins Zentrum
# host_id                                                   49896804
# host_name                                                      NaN
# neighbourhood_group                           Charlottenburg-Wilm.
# neighbourhood                                  Düsseldorfer Straße
# latitude                                                    52.498
# longitude                                                  13.3344
# room_type                                          Entire home/apt
# price                                                         9000
# minimum_nights                                                 100
# number_of_reviews                                                1
# last_review                                             2016-01-02
# reviews_per_month                                             0.03
# calculated_host_listings_count                                   1
# availability_365                                                 0
# Name: 6655, dtype: object
# id                                                                         9770154
# name                              Big Apartment in Kreuzberg, facing Viktoria Park
# host_id                                                                    3122986
# host_name                                                                 Riccardo
# neighbourhood_group                                       Friedrichshain-Kreuzberg
# neighbourhood                                                 Tempelhofer Vorstadt
# latitude                                                                   52.4899
# longitude                                                                  13.3757
# room_type                                                          Entire home/apt
# price                                                                          304
# minimum_nights                                                                   2
# number_of_reviews                                                               47
# last_review                                                             2018-10-14
# reviews_per_month                                                             1.39
# calculated_host_listings_count                                                   4
# availability_365                                                               358
# Name: 6743, dtype: object
# id                                                     10332030
# name                              STORAGE APARTMENT SONNENALLEE
# host_id                                                   86173
# host_name                                             Sebastian
# neighbourhood_group                                    Neukölln
# neighbourhood                                      Reuterstraße
# latitude                                                 52.486
# longitude                                               13.4317
# room_type                                       Entire home/apt
# price                                                       450
# minimum_nights                                                3
# number_of_reviews                                            55
# last_review                                          2018-10-13
# reviews_per_month                                          1.68
# calculated_host_listings_count                                2
# availability_365                                            340
# Name: 7174, dtype: object
# id                                                             10641148
# name                              28 BED ROOM / 8 RO. APARTMENT/ HOSTEL
# host_id                                                        54942921
# host_name                                                         Alina
# neighbourhood_group                                               Mitte
# neighbourhood                                         Regierungsviertel
# latitude                                                        52.5118
# longitude                                                       13.3843
# room_type                                                  Private room
# price                                                               899
# minimum_nights                                                        1
# number_of_reviews                                                     0
# last_review                                                         NaN
# reviews_per_month                                                   NaN
# calculated_host_listings_count                                       18
# availability_365                                                    365
# Name: 7304, dtype: object
# id                                                  11384240
# name                              Fusion Factory Event Space
# ...
# host_name                                                       Hotel Zoo
# neighbourhood_group                                  Charlottenburg-Wilm.
# neighbourhood                                              Kurfürstendamm
# latitude                                                          52.5034
# longitude                                                          13.328
# room_type                                                    Private room
# price                                                                 650
# minimum_nights                                                          1
# number_of_reviews                                                       0
# last_review                                                           NaN
# reviews_per_month                                                     NaN
# calculated_host_listings_count                                          7
# availability_365                                                      235
# Name: 21700, dtype: object
# id                                         29022451
# name                              Gorki Penthouse 2
# host_id                                    42671030
# host_name                          Gorki Apartments
# neighbourhood_group                           Mitte
# neighbourhood                       Brunnenstr. Süd
# latitude                                    52.5315
# longitude                                   13.4008
# room_type                           Entire home/apt
# price                                           900
# minimum_nights                                    1
# number_of_reviews                                 0
# last_review                                     NaN
# reviews_per_month                               NaN
# calculated_host_listings_count                    6
# availability_365                                207
# Name: 21825, dtype: object
# id                                         29022524
# name                              Gorki Penthouse 1
# host_id                                    42671030
# host_name                          Gorki Apartments
# neighbourhood_group                           Mitte
# neighbourhood                       Brunnenstr. Süd
# latitude                                    52.5304
# longitude                                   13.4028
# room_type                           Entire home/apt
# price                                          1000
# minimum_nights                                    1
# number_of_reviews                                 0
# last_review                                     NaN
# reviews_per_month                               NaN
# calculated_host_listings_count                    6
# availability_365                                199
# Name: 21826, dtype: object
# id                                                                         29090853
# name                              Gemütliches Wannsee Sauna, Kamin, Musikinstrum...
# host_id                                                                   201653787
# host_name                                                                   Ewelina
# neighbourhood_group                                           Steglitz - Zehlendorf
# neighbourhood                                                   Zehlendorf  Südwest
# latitude                                                                    52.4179
# longitude                                                                   13.1543
# room_type                                                           Entire home/apt
# price                                                                           400
# minimum_nights                                                                    7
# number_of_reviews                                                                 0
# last_review                                                                     NaN
# reviews_per_month                                                               NaN
# calculated_host_listings_count                                                    2
# availability_365                                                                 54
# Name: 21878, dtype: object
# id                                                                  29155985
# name                              Wannsee gemütlich, Kamin, Flügel, Gitarren
# host_id                                                            201653787
# host_name                                                            Ewelina
# neighbourhood_group                                    Steglitz - Zehlendorf
# neighbourhood                                            Zehlendorf  Südwest
# latitude                                                             52.4178
# longitude                                                            13.1542
# room_type                                                    Entire home/apt
# price                                                                    400
# minimum_nights                                                             5
# number_of_reviews                                                          0
# last_review                                                              NaN
# reviews_per_month                                                        NaN
# calculated_host_listings_count                                             2
# availability_365                                                          13
# Name: 21944, dtype: object
# id                                                                         29404789
# name                              Awesome Loft with huge terrace and an amazing ...
# host_id                                                                    16267190
# host_name                                                                    Volker
# neighbourhood_group                                                          Pankow
# neighbourhood                                                   Prenzlauer Berg Süd
# latitude                                                                    52.5391
# longitude                                                                   13.4295
# room_type                                                           Entire home/apt
# price                                                                           400
# minimum_nights                                                                    4
# number_of_reviews                                                                 0
# last_review                                                                     NaN
# reviews_per_month                                                               NaN
# calculated_host_listings_count                                                    2
# availability_365                                                                 25
# Name: 22118, dtype: object
# id                                                                      29430390
# name                              Trisonette Wohnung - Berlin Grunewald - 339 qm
# host_id                                                                221687266
# host_name                                                           Till & Aniko
# neighbourhood_group                                         Charlottenburg-Wilm.
# neighbourhood                                                          Grunewald
# latitude                                                                 52.4924
# longitude                                                                13.2744
# room_type                                                        Entire home/apt
# price                                                                        350
# minimum_nights                                                                 4
# number_of_reviews                                                              2
# last_review                                                           2018-11-04
# reviews_per_month                                                              2
# calculated_host_listings_count                                                 1
# availability_365                                                             153
# Name: 22143, dtype: object
# id                                                      29509869
# name                                             Penthouse Suite
# host_id                                                 93102678
# host_name                         Apartments Rosenthal Residence
# neighbourhood_group                                        Mitte
# neighbourhood                                     Alexanderplatz
# latitude                                                 52.5294
# longitude                                                13.4029
# room_type                                           Private room
# price                                                        400
# minimum_nights                                                 1
# number_of_reviews                                              0
# last_review                                                  NaN
# reviews_per_month                                            NaN
# calculated_host_listings_count                                 5
# availability_365                                             346
# Name: 22220, dtype: object
# id                                               29546155
# name                              Berlin Mehrparteienhaus
# host_id                                         222457038
# host_name                                           Walid
# neighbourhood_group                               Spandau
# neighbourhood                          Brunsbütteler Damm
# latitude                                          52.5402
# longitude                                         13.1632
# room_type                                 Entire home/apt
# price                                                 400
# minimum_nights                                          4
# number_of_reviews                                       0
# last_review                                           NaN
# reviews_per_month                                     NaN
# calculated_host_listings_count                          1
# availability_365                                      364
# Name: 22253, dtype: object
# id                                                                         29642132
# name                              Einzigartiges Penthouse über den Dächern Berlins!
# host_id                                                                     4332893
# host_name                                                                    Oliver
# neighbourhood_group                                                           Mitte
# neighbourhood                                                        Alexanderplatz
# latitude                                                                    52.5267
# longitude                                                                   13.3866
# room_type                                                           Entire home/apt
# price                                                                           650
# minimum_nights                                                                    3
# number_of_reviews                                                                 0
# last_review                                                                     NaN
# reviews_per_month                                                               NaN
# calculated_host_listings_count                                                    1
# availability_365                                                                251
# Name: 22332, dtype: object
# id                                                         29684637
# name                              Cool Luxury meets Amazing Design!
# host_id                                                   134939989
# host_name                                     Lux Travel Collective
# neighbourhood_group                                           Mitte
# neighbourhood                                        Alexanderplatz
# latitude                                                    52.5055
# longitude                                                   13.4204
# room_type                                           Entire home/apt
# price                                                          1500
# minimum_nights                                                   10
# number_of_reviews                                                 0
# last_review                                                     NaN
# reviews_per_month                                               NaN
# calculated_host_listings_count                                    2
# availability_365                                                 90
# Name: 22372, dtype: object
# id                                                   29706171
# name                              Most amazing flat in Berlin
# host_id                                              71934837
# host_name                                             Tassilo
# neighbourhood_group                                     Mitte
# neighbourhood                                 Wedding Zentrum
# latitude                                              52.5508
# longitude                                             13.3699
# room_type                                        Private room
# price                                                    1000
# minimum_nights                                              1
# number_of_reviews                                           0
# last_review                                               NaN
# reviews_per_month                                         NaN
# calculated_host_listings_count                              1
# availability_365                                          364
# Name: 22395, dtype: object
# id                                                                  29840432
# name                              !!! EDLES PENTHOUSE !!! NÄHE KUFÜRSTENDAMM
# host_id                                                            144967129
# host_name                                                             Samuel
# neighbourhood_group                                   Tempelhof - Schöneberg
# neighbourhood                                                Schöneberg-Nord
# latitude                                                             52.4948
# longitude                                                            13.3445
# room_type                                                       Private room
# price                                                                    599
# minimum_nights                                                             1
# number_of_reviews                                                          0
# last_review                                                              NaN
# reviews_per_month                                                        NaN
# calculated_host_listings_count                                             3
# availability_365                                                         364
# Name: 22526, dtype: object
# id                                                             29841234
# name                              !!! PENTHOUSE !!! NÄHE KURFÜRSTENDAMM
# host_id                                                       144967129
# host_name                                                        Samuel
# neighbourhood_group                              Tempelhof - Schöneberg
# neighbourhood                                           Schöneberg-Nord
# latitude                                                        52.4947
# longitude                                                       13.3446
# room_type                                                  Private room
# price                                                               399
# minimum_nights                                                        1
# number_of_reviews                                                     0
# last_review                                                         NaN
# reviews_per_month                                                   NaN
# calculated_host_listings_count                                        3
# availability_365                                                    364
# Name: 22527, dtype: object

# %%
from matplotlib.pyplot import figure
from pylab import *
figure(figsize=(10,2))
ng = dataset.iloc[:,[10]]
y = []
for i in range(len(ng)):
    y.append(0)
plt.scatter(ng, y, s = 100, c = 'black')
plt.title('min night')
plt.show()
#Plot data min night untuk mencari data yang tidak biasa

# %%
# unusualminNight = []
# unusualminNight.extend(dataset[dataset['minimum_nights'] > 600].index.tolist())
# print(unusualminNight)

# %%
# for i in range (len(unusualminNight)):
#     print(dataset.iloc[unusualminNight[i],:])
# #melihat informasi data

# %%
from matplotlib.pyplot import figure
from pylab import *
figure(figsize=(10,2))
ng = dataset.iloc[:,[11]]
y = []
for i in range(len(ng)):
    y.append(0)
plt.scatter(ng, y, s = 100, c = 'black')
plt.title('num_review')
plt.show()
#Plot data num_review untuk mencari data yang tidak biasa

# %%
# unusualReview = []
# unusualReview.extend(dataset[dataset['number_of_reviews'] > 450].index.tolist())
# print(unusualReview)

# %%
# for i in range (len(unusualReview)):
#     print(dataset.iloc[unusualReview[i],:])
# #melihat informasi data

# %%
from matplotlib.pyplot import figure
from pylab import *
figure(figsize=(10,2))
ng = dataset.iloc[:,[14]]
y = []
for i in range(len(ng)):
    y.append(0)
plt.scatter(ng, y, s = 100, c = 'black')
plt.title('calculated_host_listings_count')
plt.show()
#Plot data calculated_host_listings_count untuk mencari data yang tidak biasa

# %%
from matplotlib.pyplot import figure
from pylab import *
figure(figsize=(10,2))
ng = dataset.iloc[:,[15]]
y = []
for i in range(len(ng)):
    y.append(0)
plt.scatter(ng, y, s = 100, c = 'black')
plt.title('availability_365')
plt.show()
#Plot data availability_365 untuk mencari data yang tidak biasa

# %%
# #terdapat 3 list yang memiliki data tidak biasa
# unusualData = []
# unusualData.extend(unusualPrice)
# # unusualData.extend(unusualminNight)
# # unusualData.extend(unusualReview)
# unusualData.extend(idx)
# unusualData = list(dict.fromkeys(unusualData))
# unusualData.sort(reverse = True)
# #Memasukan seluruh data yang tidak biasa dan bernilai null
# #Tidak digunakan karena listing tetap ditemukan pada situs airbnb ada di laporan untuk penjelasan
# # unusualData

# %%
nullValue = []
nullValue.extend(dataset[dataset['name'].isnull()].index.tolist())
#Mengumpulkan index dari data null atribute name
nullValue.extend(dataset[dataset['host_name'].isnull()].index.tolist())
#Mengumpulkan index dari data null atribute host_name
nullValue.extend(dataset[dataset['last_review'].isnull()].index.tolist())
#Mengumpulkan index dari data null atribute last_review
nullValue.extend(dataset[dataset['reviews_per_month'].isnull()].index.tolist())
#Mengumpulkan index dari data null atribute reviews_per_month
nullValue.extend(unusualPrice)
#menghapus data outlier
nullValue = list(dict.fromkeys(nullValue))
#Penghapusan data yang duplikat dalam list idx
len(nullValue)
# Out:
# 4064

# %%
#delete null + outlier
print("Awal: ", len(dataset))
print("Banyak data yang dihapus: ", len(nullValue))
dataset.drop(nullValue, inplace = True)
print("Akhir: ", len(dataset))
print(dataset.isnull().sum())
print(dataset.info())
# Out:
# Awal:  22552
# Banyak data yang dihapus:  4064
# Akhir:  18488
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18488 entries, 0 to 22536
# Data columns (total 16 columns):
# id                                18488 non-null int64
# name                              18488 non-null object
# host_id                           18488 non-null int64
# host_name                         18488 non-null object
# neighbourhood_group               18488 non-null object
# neighbourhood                     18488 non-null object
# latitude                          18488 non-null float64
# longitude                         18488 non-null float64
# room_type                         18488 non-null object
# price                             18488 non-null int64
# minimum_nights                    18488 non-null int64
# number_of_reviews                 18488 non-null int64
# last_review                       18488 non-null object
# reviews_per_month                 18488 non-null float64
# calculated_host_listings_count    18488 non-null int64
# availability_365                  18488 non-null int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 2.4+ MB
# None

# %%
from matplotlib.pyplot import figure
figure(figsize=(10,2))
ng = dataset.iloc[:,[9]]
y = []
for i in range(len(ng)):
    y.append(0)
plt.scatter(ng, y, s = 100, c = 'black')
plt.title('Price With Outlier')
plt.show()
#Plot data price

# %%
#end preprocessing
dataset
# Out:
#              id                                               name    host_id  \
# 0          2015   Berlin-Mitte Value! Quiet courtyard/very central       2217
# 1          2695                 Prenzlauer Berg close to Mauerpark       2986
# 2          3176                    Fabulous Flat in great Location       3718
# 3          3309                  BerlinSpot Schöneberg near KaDeWe       4108
# 4          7071                   BrightRoom with sunny greenview!      17391
# ...         ...                                                ...        ...
# 22449  29772631                 Cosy and lovely room near Ostkreuz   20727291
# 22463  29784461     House on the water HT10 - Heart of East Berlin   22437698
# 22475  29792124                         Welcome to Light Apartment  224133729
# 22508  29817383                                     Prenzlauerberg  224295751
# 22536  29849565  Super zentrales Apartment + Garten für 6 Personen     607481
#
#        host_name       neighbourhood_group             neighbourhood  \
# 0            Ian                     Mitte           Brunnenstr. Süd
# 1        Michael                    Pankow  Prenzlauer Berg Nordwest
# 2         Britta                    Pankow   Prenzlauer Berg Südwest
# 3           Jana    Tempelhof - Schöneberg           Schöneberg-Nord
# 4         Bright                    Pankow            Helmholtzplatz
# ...          ...                       ...                       ...
# 22449       Anna               Lichtenberg           Neu Lichtenberg
# 22463  Sebastian        Treptow - Köpenick           Oberschöneweide
# 22475       Inna  Friedrichshain-Kreuzberg  Frankfurter Allee Süd FK
# 22508      Salem                    Pankow  Prenzlauer Berg Nordwest
# 22536       Sven                    Pankow   Prenzlauer Berg Südwest
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      52.534537  13.402557  Entire home/apt     60               4
# 1      52.548513  13.404553     Private room     17               2
# 2      52.534996  13.417579  Entire home/apt     90              62
# 3      52.498855  13.349065     Private room     26               5
# 4      52.543157  13.415091     Private room     42               2
# ...          ...        ...              ...    ...             ...
# 22449  52.502952  13.490870     Private room     25               2
# 22463  52.457982  13.526945  Entire home/apt     99               1
# 22475  52.507884  13.467071     Private room     25               1
# 22508  52.552250  13.410904  Entire home/apt     70               1
# 22536  52.536666  13.411360  Entire home/apt    150              10
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                    118  2018-10-28               3.76
# 1                      6  2018-10-01               1.42
# 2                    143  2017-03-20               1.25
# 3                     25  2018-08-16               0.39
# 4                    197  2018-11-04               1.75
# ...                  ...         ...                ...
# 22449                  1  2018-11-04               1.00
# 22463                  5  2018-11-06               5.00
# 22475                  1  2018-11-05               1.00
# 22508                  1  2018-11-07               1.00
# 22536                  2  2018-11-07               2.00
#
#        calculated_host_listings_count  availability_365
# 0                                   4               141
# 1                                   1                 0
# 2                                   1               220
# 3                                   1               297
# 4                                   1                26
# ...                               ...               ...
# 22449                               1                32
# 22463                               2               339
# 22475                               1                 8
# 22508                               1               350
# 22536                               1                69
#
# [18488 rows x 16 columns]

# %%
klasifikasiDataset = dataset.copy()
klasifikasiDataset = klasifikasiDataset.drop(['id', 'name', 'host_id', 'host_name' ,'latitude','longitude','last_review'], axis = 1)
#Penghapusan atribut yang dapat mengurangi akurasi

# %%
klasifikasiDataset
# Out:
#             neighbourhood_group             neighbourhood        room_type  \
# 0                         Mitte           Brunnenstr. Süd  Entire home/apt
# 1                        Pankow  Prenzlauer Berg Nordwest     Private room
# 2                        Pankow   Prenzlauer Berg Südwest  Entire home/apt
# 3        Tempelhof - Schöneberg           Schöneberg-Nord     Private room
# 4                        Pankow            Helmholtzplatz     Private room
# ...                         ...                       ...              ...
# 22449               Lichtenberg           Neu Lichtenberg     Private room
# 22463        Treptow - Köpenick           Oberschöneweide  Entire home/apt
# 22475  Friedrichshain-Kreuzberg  Frankfurter Allee Süd FK     Private room
# 22508                    Pankow  Prenzlauer Berg Nordwest  Entire home/apt
# 22536                    Pankow   Prenzlauer Berg Südwest  Entire home/apt
#
#        price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0         60               4                118               3.76
# 1         17               2                  6               1.42
# 2         90              62                143               1.25
# 3         26               5                 25               0.39
# 4         42               2                197               1.75
# ...      ...             ...                ...                ...
# 22449     25               2                  1               1.00
# 22463     99               1                  5               5.00
# 22475     25               1                  1               1.00
# 22508     70               1                  1               1.00
# 22536    150              10                  2               2.00
#
#        calculated_host_listings_count  availability_365
# 0                                   4               141
# 1                                   1                 0
# 2                                   1               220
# 3                                   1               297
# 4                                   1                26
# ...                               ...               ...
# 22449                               1                32
# 22463                               2               339
# 22475                               1                 8
# 22508                               1               350
# 22536                               1                69
#
# [18488 rows x 9 columns]

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder = LabelEncoder()
klasifikasiDataset.iloc[:, [0]] = labelencoder.fit_transform(klasifikasiDataset.iloc[:, [0]])
#label encoder digunakan untuk membantu dalam kalkulasi feature selection dalam atribut neighbourhood_group
klasifikasiDataset.iloc[:, [1]] = labelencoder.fit_transform(klasifikasiDataset.iloc[:, [1]])
#label encoder digunakan untuk membantu dalam kalkulasi feature selection dalam atribut neighbourhood
klasifikasiDataset
# Out:
# C:\Anaconda\lib\site-packages\sklearn\preprocessing\label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#        neighbourhood_group  neighbourhood        room_type  price  \
# 0                        4             18  Entire home/apt     60
# 1                        6             95     Private room     17
# 2                        6             98  Entire home/apt     90
# 3                       10            110     Private room     26
# 4                        6             49     Private room     42
# ...                    ...            ...              ...    ...
# 22449                    2             76     Private room     25
# 22463                   11             84  Entire home/apt     99
# 22475                    1             32     Private room     25
# 22508                    6             95  Entire home/apt     70
# 22536                    6             98  Entire home/apt    150
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 0                   4                118               3.76
# 1                   2                  6               1.42
# 2                  62                143               1.25
# 3                   5                 25               0.39
# 4                   2                197               1.75
# ...               ...                ...                ...
# 22449               2                  1               1.00
# 22463               1                  5               5.00
# 22475               1                  1               1.00
# 22508               1                  1               1.00
# 22536              10                  2               2.00
#
#        calculated_host_listings_count  availability_365
# 0                                   4               141
# 1                                   1                 0
# 2                                   1               220
# 3                                   1               297
# 4                                   1                26
# ...                               ...               ...
# 22449                               1                32
# 22463                               2               339
# 22475                               1                 8
# 22508                               1               350
# 22536                               1                69
#
# [18488 rows x 9 columns]

# %%
print(Counter(klasifikasiDataset["room_type"]))
#Menghitung record room_type
# Out:
# Counter({'Private room': 9518, 'Entire home/apt': 8753, 'Shared room': 217})

# %%
#Feature Selection
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
atr2Sellect = klasifikasiDataset.iloc[:,[0,1,3,4,5,6,7,8]]
#Pengambilan keseluruhan atribut untuk dicari pengaruhnya terhadap atribut kelas
cls2Sellect = klasifikasiDataset.iloc[:,2]
#atribut kelas yaitu room_type
#penggunaan SelectKBest class untuk mencari fitur terbaik
bestfeatures = SelectKBest(score_func=chi2, k='all')
fit = bestfeatures.fit(atr2Sellect,cls2Sellect)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(atr2Sellect.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Attribute','Score']  #Menamai Kolom
print(featureScores.nlargest(8,'Score'))  #print fitur terbaik secara terurut
# Out:
#                         Attribute          Score
# 2                           price  119479.656282
# 7                availability_365   38524.865991
# 3                  minimum_nights   22076.811595
# 6  calculated_host_listings_count    6674.715731
# 4               number_of_reviews    2298.210106
# 1                   neighbourhood     844.069208
# 5               reviews_per_month      27.875700
# 0             neighbourhood_group      18.386999

# %%
prosesKlasifikasi = klasifikasiDataset.copy()

# %%
#start of decision tree

# %%
#prediksi Room type
#Dengan price, availability_365, dan minimum_nights 
#Kelas adalah room_type
X = prosesKlasifikasi.iloc[:, [3, 8, 4]].values
y = prosesKlasifikasi.iloc[:, 2].values

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)
#X_train merupakan atribut fitur yang akan menjadi data latih
#y_train merupakan kelasnya
#X_test nantinya digunakan untuk melakukan prediksi dari model yang telah digunakan
#y_test adalah kelas yang akan dibandingkan dengan hasil prediksi

# %%
# Fitting Decision Tree Classification to the Training set
from sklearn.tree import DecisionTreeClassifier, plot_tree
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
#penggunakan library DecisionTreeClassifier dari sklearn
classifier.fit(X_train, y_train)
#melakukan pemodelan
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=0, splitter='best')

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
#memberikan report hasil evaluasi
# Out:
# [[1359  384    6]
#  [ 401 1480   20]
#  [   4   35    9]]
#                  precision    recall  f1-score   support
#
# Entire home/apt       0.77      0.78      0.77      1749
#    Private room       0.78      0.78      0.78      1901
#     Shared room       0.26      0.19      0.22        48
#
#        accuracy                           0.77      3698
#       macro avg       0.60      0.58      0.59      3698
#    weighted avg       0.77      0.77      0.77      3698

# %%
#Accuracy CM
acc = sum(cm.diagonal()) / sum(cm[0] + cm[1] + cm[2])
print("Accuracy: ", acc)
#Precission 
PrecissionA = cm[0][0] / sum(cm[0])
print("Precission A: ", PrecissionA)
PrecissionB = cm[1][1] / sum(cm[1])
print("Precission B: ", PrecissionB)
PrecissionC = cm[2][2] / sum(cm[2])
print("Precission C: ", PrecissionC)
#Recall
recA = cm[0][0] / sum(cm[:,0])
print("Recall A: ", recA)
recB = cm[1][1] / sum(cm[:,1])
print("Recall B: ", recB)
recC = cm[2][2] / sum(cm[:,2])
print("Recall C: ", recC)
# Out:
# Accuracy:  0.7701460248783126
# Precission A:  0.7770154373927959
# Precission B:  0.778537611783272
# Precission C:  0.1875
# Recall A:  0.7704081632653061
# Recall B:  0.7793575566087414
# Recall C:  0.2571428571428571

# %%
#end of decision tree

# %%
#Start of KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=500).fit(X_train,y_train)
#penggunakan library KNeighborsClassifier dari sklearn dengan jumlah N sebanyak 500
classifier.fit(X_train, y_train)
#melakukan pemodelan
# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
#memberikan report hasil evaluasi
# Out:
# [[1359  390    0]
#  [ 320 1581    0]
#  [   3   45    0]]
#                  precision    recall  f1-score   support
#
# Entire home/apt       0.81      0.78      0.79      1749
#    Private room       0.78      0.83      0.81      1901
#     Shared room       0.00      0.00      0.00        48
#
#        accuracy                           0.80      3698
#       macro avg       0.53      0.54      0.53      3698
#    weighted avg       0.79      0.80      0.79      3698
# C:\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
#Accuracy CM
acc = sum(cm.diagonal()) / sum(cm[0] + cm[1] + cm[2])
print("Accuracy: ", acc)
#Precission 
PrecissionA = cm[0][0] / sum(cm[0])
print("Precission A: ", PrecissionA)
PrecissionB = cm[1][1] / sum(cm[1])
print("Precission B: ", PrecissionB)
PrecissionC = cm[2][2] / sum(cm[2])
print("Precission C: ", PrecissionC)
#Recall
recA = cm[0][0] / sum(cm[:,0])
print("Recall A: ", recA)
recB = cm[1][1] / sum(cm[:,1])
print("Recall B: ", recB)
recC = cm[2][2] / sum(cm[:,2])
print("Recall C: ", recC)
# Out:
# Accuracy:  0.7950243374797188
# Precission A:  0.7770154373927959
# Precission B:  0.8316675433982115
# Precission C:  0.0
# Recall A:  0.8079667063020214
# Recall B:  0.7842261904761905
# Recall C:  nan
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in longlong_scalars
#   app.launch_new_instance()

# %%
#clustering

# %%
#k Means

# %%
dataset
# Out:
#              id                                               name    host_id  \
# 0          2015   Berlin-Mitte Value! Quiet courtyard/very central       2217
# 1          2695                 Prenzlauer Berg close to Mauerpark       2986
# 2          3176                    Fabulous Flat in great Location       3718
# 3          3309                  BerlinSpot Schöneberg near KaDeWe       4108
# 4          7071                   BrightRoom with sunny greenview!      17391
# ...         ...                                                ...        ...
# 22449  29772631                 Cosy and lovely room near Ostkreuz   20727291
# 22463  29784461     House on the water HT10 - Heart of East Berlin   22437698
# 22475  29792124                         Welcome to Light Apartment  224133729
# 22508  29817383                                     Prenzlauerberg  224295751
# 22536  29849565  Super zentrales Apartment + Garten für 6 Personen     607481
#
#        host_name       neighbourhood_group             neighbourhood  \
# 0            Ian                     Mitte           Brunnenstr. Süd
# 1        Michael                    Pankow  Prenzlauer Berg Nordwest
# 2         Britta                    Pankow   Prenzlauer Berg Südwest
# 3           Jana    Tempelhof - Schöneberg           Schöneberg-Nord
# 4         Bright                    Pankow            Helmholtzplatz
# ...          ...                       ...                       ...
# 22449       Anna               Lichtenberg           Neu Lichtenberg
# 22463  Sebastian        Treptow - Köpenick           Oberschöneweide
# 22475       Inna  Friedrichshain-Kreuzberg  Frankfurter Allee Süd FK
# 22508      Salem                    Pankow  Prenzlauer Berg Nordwest
# 22536       Sven                    Pankow   Prenzlauer Berg Südwest
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      52.534537  13.402557  Entire home/apt     60               4
# 1      52.548513  13.404553     Private room     17               2
# 2      52.534996  13.417579  Entire home/apt     90              62
# 3      52.498855  13.349065     Private room     26               5
# 4      52.543157  13.415091     Private room     42               2
# ...          ...        ...              ...    ...             ...
# 22449  52.502952  13.490870     Private room     25               2
# 22463  52.457982  13.526945  Entire home/apt     99               1
# 22475  52.507884  13.467071     Private room     25               1
# 22508  52.552250  13.410904  Entire home/apt     70               1
# 22536  52.536666  13.411360  Entire home/apt    150              10
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                    118  2018-10-28               3.76
# 1                      6  2018-10-01               1.42
# 2                    143  2017-03-20               1.25
# 3                     25  2018-08-16               0.39
# 4                    197  2018-11-04               1.75
# ...                  ...         ...                ...
# 22449                  1  2018-11-04               1.00
# 22463                  5  2018-11-06               5.00
# 22475                  1  2018-11-05               1.00
# 22508                  1  2018-11-07               1.00
# 22536                  2  2018-11-07               2.00
#
#        calculated_host_listings_count  availability_365
# 0                                   4               141
# 1                                   1                 0
# 2                                   1               220
# 3                                   1               297
# 4                                   1                26
# ...                               ...               ...
# 22449                               1                32
# 22463                               2               339
# 22475                               1                 8
# 22508                               1               350
# 22536                               1                69
#
# [18488 rows x 16 columns]

# %%
clusteringDataset = dataset.copy()
clusteringDataset = clusteringDataset.drop(['id', 'name', 'host_id', 'host_name' ,'latitude','longitude','last_review'], axis = 1)

# %%
clusteringDataset
# Out:
#             neighbourhood_group             neighbourhood        room_type  \
# 0                         Mitte           Brunnenstr. Süd  Entire home/apt
# 1                        Pankow  Prenzlauer Berg Nordwest     Private room
# 2                        Pankow   Prenzlauer Berg Südwest  Entire home/apt
# 3        Tempelhof - Schöneberg           Schöneberg-Nord     Private room
# 4                        Pankow            Helmholtzplatz     Private room
# ...                         ...                       ...              ...
# 22449               Lichtenberg           Neu Lichtenberg     Private room
# 22463        Treptow - Köpenick           Oberschöneweide  Entire home/apt
# 22475  Friedrichshain-Kreuzberg  Frankfurter Allee Süd FK     Private room
# 22508                    Pankow  Prenzlauer Berg Nordwest  Entire home/apt
# 22536                    Pankow   Prenzlauer Berg Südwest  Entire home/apt
#
#        price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0         60               4                118               3.76
# 1         17               2                  6               1.42
# 2         90              62                143               1.25
# 3         26               5                 25               0.39
# 4         42               2                197               1.75
# ...      ...             ...                ...                ...
# 22449     25               2                  1               1.00
# 22463     99               1                  5               5.00
# 22475     25               1                  1               1.00
# 22508     70               1                  1               1.00
# 22536    150              10                  2               2.00
#
#        calculated_host_listings_count  availability_365
# 0                                   4               141
# 1                                   1                 0
# 2                                   1               220
# 3                                   1               297
# 4                                   1                26
# ...                               ...               ...
# 22449                               1                32
# 22463                               2               339
# 22475                               1                 8
# 22508                               1               350
# 22536                               1                69
#
# [18488 rows x 9 columns]

# %%
X = clusteringDataset.iloc[:, [3, 4]].values
# atrA = MinMaxScaler().fit_transform(X[:,[0]])
# atrB = MinMaxScaler().fit_transform(X[:,[1]])
atrA = (X[:,[0]])
atrB = (X[:,[1]])
datanya = []
for i in range (len(atrA)):
    datanya.append([float(atrA[i]),float(atrB[i])])

# %%
# # Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++')
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
#generate centroid
randnum = rd.sample(range(len(datanya)), 3)
centroid = []
for i in range(len(randnum)):
    centroid.append(datanya[randnum[i]])

# %%
stat = True
while stat:
    clusters = []
    clustersidx = []
    for i in range(len(centroid)):
        clusters.append([])
        clustersidx.append([])
        #assign tempat yang akan diisi tiap cluster
    for i in range(len(datanya)):
        jarak = []
        newCentroid = []
        for j in range(len(centroid)):
            hitungan = 0
            for k in range (2): 
#               nanti ubah
                hitungan += abs(datanya[i][k]-centroid[j][k])
                #perhitungan jarak menggunakan manhattan distance
            jarak.append(hitungan)
            #insert kedalam array nilai-nilai jarak dari tiap centroid
        minIdx = jarak.index(min(jarak))
        #mendapatkan index dari jarak paling rendah (centroid ke-minIdx)
#         for k in range (2): 
        clusters[minIdx].append(datanya[i])
        #insert data kedalam clusters tertentu
        #
        clustersidx[minIdx].append(i)
        #insert index kedalam clusters tertentu
    newCentroid = []
    for i in range(len(centroid)):
        totalAtr0 = 0
        totalAtr1 = 0
        #atur sebanyak atr
        for j in range(len(clusters[i])):
            totalAtr0 += clusters[i][j][0]
            totalAtr1 += clusters[i][j][1]
        newCentroid.append([totalAtr0/len(clusters[i]),totalAtr1/len(clusters[i])]) 
        #pembuatan centroid baru
    if centroid == newCentroid:
        stat = False
        #kondisi berhenti
    else:
        centroid = []
        centroid = newCentroid.copy()
        #kondisi centroid belum sama maka akan dilakukan iterasi lagi

# %%
plotCX = []
plotCY = []
for i in range(len(newCentroid)):
    plotCX.append(newCentroid[i][0])
    plotCY.append(newCentroid[i][1])

# %%
# figure(figsize=(100,100))
plt.scatter(X[clustersidx[0],[0]], X[clustersidx[0],[1]], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[clustersidx[1],[0]], X[clustersidx[1],[1]], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X[clustersidx[2],[0]], X[clustersidx[2],[1]], s = 100, c = 'green', label = 'Cluster 3')
# plt.scatter(X[clustersidx[3],[0]], X[clustersidx[3],[1]], s = 100, c = 'cyan', label = 'Cluster 4')
# plt.scatter(X[clustersidx[4],[0]], X[clustersidx[4],[1]], s = 100, c = 'magenta', label = 'Cluster 5')
# plt.scatter(X[clustersidx[5],[0]], X[clustersidx[5],[1]], s = 100, c = 'gray', label = 'Cluster 6')
# plt.scatter(X[clustersidx[6],[0]], X[clustersidx[6],[1]], s = 100, c = 'brown', label = 'Cluster 7')
plt.scatter(plotCX, plotCY, s = 150, c = 'yellow', label = 'Centroids')
plt.title('Clusters of customers')
plt.xlabel('Price')
plt.ylabel('Minimum Night')
plt.legend()
plt.show()

# %%
from sklearn import metrics
from sklearn.metrics import pairwise_distances
label = np.zeros(len(X))
for i in range(len(clustersidx)):
    label[clustersidx[i]] = i
print("Calinski-Harabasz", metrics.calinski_harabasz_score(X, label))
print("Silhouette Coefficient", metrics.silhouette_score(X, label, metric='euclidean'))
# Out:
# Calinski-Harabasz 5120.317323632956
# Silhouette Coefficient 0.5499513864632493

# %%
#Hierarki

# %%
clusteringDataset = dataset.copy()
clusteringDataset = clusteringDataset.drop(['id', 'name', 'host_id', 'host_name' ,'latitude','longitude','last_review'], axis = 1)

# %%
clusteringDataset
# Out:
#             neighbourhood_group             neighbourhood        room_type  \
# 0                         Mitte           Brunnenstr. Süd  Entire home/apt
# 1                        Pankow  Prenzlauer Berg Nordwest     Private room
# 2                        Pankow   Prenzlauer Berg Südwest  Entire home/apt
# 3        Tempelhof - Schöneberg           Schöneberg-Nord     Private room
# 4                        Pankow            Helmholtzplatz     Private room
# ...                         ...                       ...              ...
# 22449               Lichtenberg           Neu Lichtenberg     Private room
# 22463        Treptow - Köpenick           Oberschöneweide  Entire home/apt
# 22475  Friedrichshain-Kreuzberg  Frankfurter Allee Süd FK     Private room
# 22508                    Pankow  Prenzlauer Berg Nordwest  Entire home/apt
# 22536                    Pankow   Prenzlauer Berg Südwest  Entire home/apt
#
#        price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0         60               4                118               3.76
# 1         17               2                  6               1.42
# 2         90              62                143               1.25
# 3         26               5                 25               0.39
# 4         42               2                197               1.75
# ...      ...             ...                ...                ...
# 22449     25               2                  1               1.00
# 22463     99               1                  5               5.00
# 22475     25               1                  1               1.00
# 22508     70               1                  1               1.00
# 22536    150              10                  2               2.00
#
#        calculated_host_listings_count  availability_365
# 0                                   4               141
# 1                                   1                 0
# 2                                   1               220
# 3                                   1               297
# 4                                   1                26
# ...                               ...               ...
# 22449                               1                32
# 22463                               2               339
# 22475                               1                 8
# 22508                               1               350
# 22536                               1                69
#
# [18488 rows x 9 columns]

# %%
print(Counter(clusteringDataset["neighbourhood_group"]))
# Out:
# Counter({'Friedrichshain-Kreuzberg': 4570, 'Mitte': 3791, 'Pankow': 2935, 'Neukölln': 2892, 'Tempelhof - Schöneberg': 1275, 'Charlottenburg-Wilm.': 1267, 'Lichtenberg': 526, 'Treptow - Köpenick': 475, 'Steglitz - Zehlendorf': 350, 'Reinickendorf': 199, 'Marzahn - Hellersdorf': 114, 'Spandau': 94})

# %%
idxNeigh = clusteringDataset[clusteringDataset['neighbourhood_group'] != "Spandau"].index.tolist()
clusteringDataset.drop(idxNeigh, inplace = True)
clusteringDataset
# Out:
#       neighbourhood_group       neighbourhood        room_type  price  \
# 251               Spandau     Heerstraße Nord     Private room     40
# 529               Spandau      Gatow / Kladow     Private room     49
# 989               Spandau        Wilhelmstadt     Private room     77
# 1422              Spandau        Wilhelmstadt  Entire home/apt     55
# 2517              Spandau        Siemensstadt  Entire home/apt     50
# ...                   ...                 ...              ...    ...
# 21362             Spandau       Spandau Mitte      Shared room     91
# 21367             Spandau       Spandau Mitte     Private room     15
# 21518             Spandau        Wilhelmstadt     Private room     22
# 21781             Spandau  Falkenhagener Feld     Private room     16
# 22036             Spandau        Wilhelmstadt     Private room     24
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 251                 1                 26               0.34
# 529                 2                 50               0.70
# 989                 1                 13               0.31
# 1422                4                 35               0.62
# 2517               30                  4               0.08
# ...               ...                ...                ...
# 21362               1                  1               0.55
# 21367               1                 10               6.00
# 21518               2                  4               3.08
# 21781               1                  2               1.87
# 22036               1                  1               1.00
#
#        calculated_host_listings_count  availability_365
# 251                                 1               322
# 529                                 1               273
# 989                                 2               364
# 1422                                1               270
# 2517                                2               341
# ...                               ...               ...
# 21362                               1                58
# 21367                               1                57
# 21518                               1               120
# 21781                               1               302
# 22036                               2                70
#
# [94 rows x 9 columns]

# %%
X = clusteringDataset.iloc[:, [3, 4]].values
# atrA = MinMaxScaler().fit_transform(X[:,[0]])
# atrB = MinMaxScaler().fit_transform(X[:,[1]])
atrA = (X[:,[0]])
atrB = (X[:,[1]])
datanya = []
for i in range (len(atrA)):
    datanya.append([float(atrA[i]),float(atrB[i])])

# %%
from scipy.spatial import distance_matrix
from scipy.spatial.distance import squareform
from scipy.spatial.distance import pdist
mX = squareform(pdist(datanya))
# mX = squareform(X)
# print(mX)

# %%
#Inisiasi Cluster Awal
clusters = []
for i in range(len(X)):
    clusters.append([i])
# clusters
pCluster = len(X)
#nilai Cluster dapat dibuah disini
jumlahCluster = 3
while pCluster != jumlahCluster:
    close = []
    y, z = np.where( mX==np.min(mX[np.nonzero(mX)]))
    close.extend([y[-1],z[-1]])
    mustMerge = close
    #Mencari titik dari nilai terkecil pada distance matriks

    mergeClusters = []
#     print(mustMerge)
    mergeClusters.extend(clusters.pop(mustMerge[0]))
    mergeClusters.extend(clusters.pop(mustMerge[1]))                           
    clusters.append(mergeClusters)

    #Menyatukan Cluster Berdasarkan Titik

    A = mX[mustMerge[0]]
    A = np.delete(A, [mustMerge[0]], 0)
    A = np.delete(A, [mustMerge[1]], 0)
    B = mX[mustMerge[1]]
    B = np.delete(B, [mustMerge[0]], 0)
    B = np.delete(B, [mustMerge[1]], 0)
    insertThis = []
    temp = 0
    for i in range(len(A)):
    #       Start of Single Linkage
#         if A[i] <= B[i]:
#             insertThis = np.insert(insertThis, i, A[i])
#         else:
#             insertThis = np.insert(insertThis, i, B[i])
#         temp = i + 1
    #       End of Comlete Linkage

    #       Start of Comlete Linkage
            if A[i] >= B[i]:
                insertThis = np.insert(insertThis, i, A[i])
            else:
                insertThis = np.insert(insertThis, i, B[i])
            temp = i + 1
    #       End of Comlete Linkage

    #       Start of Average Linkage
#             insertThis = np.insert(insertThis,i, (A[i]+B[i])/2)
#             temp = i + 1
    #       End of Average Linkage

    insertThis = np.insert(insertThis, temp, 0)

    #Mencari nilai yang akan dimasukan ke distance Matrix

    mX = (np.delete(np.delete(mX, mustMerge[0], 0), mustMerge[0], 1))
    mX = (np.delete(np.delete(mX, mustMerge[1], 0), mustMerge[1], 1))

    #Delete distance matriks pada titik nilai minimal

    bMX = mX.copy()
    bMX = np.zeros((len(mX)+1,len(mX)+1))
    bMX[:-1,:-1] = mX
    bMX = np.insert(bMX,len(bMX)-1, insertThis, 0)
    bMX = np.delete(bMX, len(bMX)-1, axis = 0)
    bMX = np.insert(bMX,len(bMX)-1, insertThis, 1)
    bMX = np.delete(bMX, len(bMX), axis = 1)
    mX = bMX
#     print("iteration: ", pCluster)
    pCluster -= 1
    #Nilai distance matriks baru

# %%
figure(figsize=(10,10))
plt.scatter(X[clusters[0],[0]], X[clusters[0],[1]], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[clusters[1],[0]], X[clusters[1],[1]], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X[clusters[2],[0]], X[clusters[2],[1]], s = 100, c = 'green', label = 'Cluster 3')
# plt.scatter(X[clusters[3],[0]], X[clusters[3],[1]], s = 100, c = 'cyan', label = 'Cluster 4')
# plt.scatter(X[clusters[4],[0]], X[clusters[4],[1]], s = 100, c = 'magenta', label = 'Cluster 5')
# plt.scatter(X[clusters[5],[0]], X[clusters[5],[1]], s = 100, c = 'gray', label = 'Cluster 6')
# plt.scatter(X[clusters[6],[0]], X[clusters[6],[1]], s = 100, c = 'brown', label = 'Cluster 7')
plt.title('Clusters of customers in Spandau')
plt.xlabel('Price')
plt.ylabel('Minimum Night')
plt.legend()
plt.show()

# %%
label = np.zeros(len(X))
for i in range(len(clusters)):
    label[clusters[i]] = i
print("Calinski-Harabasz", metrics.calinski_harabasz_score(X, label))
print("Silhouette Coefficient", metrics.silhouette_score(X, label, metric='euclidean'))
# Out:
# Calinski-Harabasz 113.52658954621614
# Silhouette Coefficient 0.492426692653275

# %%
clusteringDataset = dataset.copy()
clusteringDataset = clusteringDataset.drop(['id', 'name', 'host_id', 'host_name' ,'latitude','longitude','last_review'], axis = 1)
print(Counter(clusteringDataset["neighbourhood_group"]))
# Out:
# Counter({'Friedrichshain-Kreuzberg': 4570, 'Mitte': 3791, 'Pankow': 2935, 'Neukölln': 2892, 'Tempelhof - Schöneberg': 1275, 'Charlottenburg-Wilm.': 1267, 'Lichtenberg': 526, 'Treptow - Köpenick': 475, 'Steglitz - Zehlendorf': 350, 'Reinickendorf': 199, 'Marzahn - Hellersdorf': 114, 'Spandau': 94})

# %%
idxNeigh = clusteringDataset[clusteringDataset['neighbourhood_group'] != "Lichtenberg"].index.tolist()
clusteringDataset.drop(idxNeigh, inplace = True)
clusteringDataset
# Out:
#       neighbourhood_group              neighbourhood        room_type  price  \
# 113           Lichtenberg        Rummelsburger Bucht  Entire home/apt     59
# 156           Lichtenberg                 Karlshorst  Entire home/apt     65
# 159           Lichtenberg            Alt-Lichtenberg     Private room     38
# 169           Lichtenberg            Neu Lichtenberg     Private room     49
# 541           Lichtenberg            Neu Lichtenberg  Entire home/apt     30
# ...                   ...                        ...              ...    ...
# 22065         Lichtenberg            Neu Lichtenberg     Private room     25
# 22081         Lichtenberg            Alt-Lichtenberg     Private room     35
# 22086         Lichtenberg            Neu Lichtenberg     Private room     30
# 22330         Lichtenberg  Alt-Hohenschönhausen Nord     Private room     27
# 22449         Lichtenberg            Neu Lichtenberg     Private room     25
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 113                 1                 28               0.35
# 156                 3                 33               0.40
# 159                 3                101               1.17
# 169                 2                129               1.49
# 541                 3                  3               0.04
# ...               ...                ...                ...
# 22065               1                  1               1.00
# 22081               5                  1               1.00
# 22086               2                  3               3.00
# 22330               1                  3               3.00
# 22449               2                  1               1.00
#
#        calculated_host_listings_count  availability_365
# 113                                 2                16
# 156                                 6               328
# 159                                 2               142
# 169                                 1                21
# 541                                 1                 0
# ...                               ...               ...
# 22065                               1               297
# 22081                               1               252
# 22086                               1                 4
# 22330                               1                21
# 22449                               1                32
#
# [526 rows x 9 columns]

# %%
X = clusteringDataset.iloc[:, [3, 4]].values
# atrA = MinMaxScaler().fit_transform(X[:,[0]])
# atrB = MinMaxScaler().fit_transform(X[:,[1]])
atrA = (X[:,[0]])
atrB = (X[:,[1]])
datanya = []
for i in range (len(atrA)):
    datanya.append([float(atrA[i]),float(atrB[i])])

# %%
mX = squareform(pdist(datanya))
# mX = squareform(X)
# print(mX)

# %%
#Inisiasi Cluster Awal
clusters = []
for i in range(len(X)):
    clusters.append([i])
# clusters
pCluster = len(X)
#nilai Cluster dapat dibuah disini
jumlahCluster = 3
while pCluster != jumlahCluster:
    close = []
    y, z = np.where( mX==np.min(mX[np.nonzero(mX)]))
    close.extend([y[-1],z[-1]])
    mustMerge = close
    #Mencari titik dari nilai terkecil pada distance matriks

    mergeClusters = []
#     print(mustMerge)
    mergeClusters.extend(clusters.pop(mustMerge[0]))
    mergeClusters.extend(clusters.pop(mustMerge[1]))                           
    clusters.append(mergeClusters)

    #Menyatukan Cluster Berdasarkan Titik

    A = mX[mustMerge[0]]
    A = np.delete(A, [mustMerge[0]], 0)
    A = np.delete(A, [mustMerge[1]], 0)
    B = mX[mustMerge[1]]
    B = np.delete(B, [mustMerge[0]], 0)
    B = np.delete(B, [mustMerge[1]], 0)
    insertThis = []
    temp = 0
    for i in range(len(A)):
    #       Start of Single Linkage
#         if A[i] <= B[i]:
#             insertThis = np.insert(insertThis, i, A[i])
#         else:
#             insertThis = np.insert(insertThis, i, B[i])
#         temp = i + 1
    #       End of Comlete Linkage

    #       Start of Comlete Linkage
            if A[i] >= B[i]:
                insertThis = np.insert(insertThis, i, A[i])
            else:
                insertThis = np.insert(insertThis, i, B[i])
            temp = i + 1
    #       End of Comlete Linkage

    #       Start of Average Linkage
#             insertThis = np.insert(insertThis,i, (A[i]+B[i])/2)
#             temp = i + 1
    #       End of Average Linkage

    insertThis = np.insert(insertThis, temp, 0)

    #Mencari nilai yang akan dimasukan ke distance Matrix

    mX = (np.delete(np.delete(mX, mustMerge[0], 0), mustMerge[0], 1))
    mX = (np.delete(np.delete(mX, mustMerge[1], 0), mustMerge[1], 1))

    #Delete distance matriks pada titik nilai minimal

    bMX = mX.copy()
    bMX = np.zeros((len(mX)+1,len(mX)+1))
    bMX[:-1,:-1] = mX
    bMX = np.insert(bMX,len(bMX)-1, insertThis, 0)
    bMX = np.delete(bMX, len(bMX)-1, axis = 0)
    bMX = np.insert(bMX,len(bMX)-1, insertThis, 1)
    bMX = np.delete(bMX, len(bMX), axis = 1)
    mX = bMX
#     print("iteration: ", pCluster)
    pCluster -= 1
    #Nilai distance matriks baru

# %%
figure(figsize=(10,10))
plt.scatter(X[clusters[0],[0]], X[clusters[0],[1]], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[clusters[1],[0]], X[clusters[1],[1]], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X[clusters[2],[0]], X[clusters[2],[1]], s = 100, c = 'green', label = 'Cluster 3')
# plt.scatter(X[clusters[3],[0]], X[clusters[3],[1]], s = 100, c = 'cyan', label = 'Cluster 4')
# plt.scatter(X[clusters[4],[0]], X[clusters[4],[1]], s = 100, c = 'magenta', label = 'Cluster 5')
# plt.scatter(X[clusters[5],[0]], X[clusters[5],[1]], s = 100, c = 'gray', label = 'Cluster 6')
# plt.scatter(X[clusters[6],[0]], X[clusters[6],[1]], s = 100, c = 'brown', label = 'Cluster 7')
plt.title('Clusters of customers in Lichtenberg')
plt.xlabel('Price')
plt.ylabel('Minimum Night')
plt.legend()
plt.show()

# %%
label = np.zeros(len(X))
for i in range(len(clusters)):
    label[clusters[i]] = i
print("Calinski-Harabasz", metrics.calinski_harabasz_score(X, label))
print("Silhouette Coefficient", metrics.silhouette_score(X, label, metric='euclidean'))
# Out:
# Calinski-Harabasz 325.6886699167166
# Silhouette Coefficient 0.7507448422525883

# %%
clusteringDataset = dataset.copy()
clusteringDataset = clusteringDataset.drop(['id', 'name', 'host_id', 'host_name' ,'latitude','longitude','last_review'], axis = 1)
print(Counter(clusteringDataset["neighbourhood_group"]))
# Out:
# Counter({'Friedrichshain-Kreuzberg': 4570, 'Mitte': 3791, 'Pankow': 2935, 'Neukölln': 2892, 'Tempelhof - Schöneberg': 1275, 'Charlottenburg-Wilm.': 1267, 'Lichtenberg': 526, 'Treptow - Köpenick': 475, 'Steglitz - Zehlendorf': 350, 'Reinickendorf': 199, 'Marzahn - Hellersdorf': 114, 'Spandau': 94})

# %%
idxNeigh = clusteringDataset[clusteringDataset['neighbourhood_group'] != "Tempelhof - Schöneberg"].index.tolist()
clusteringDataset.drop(idxNeigh, inplace = True)
clusteringDataset
# Out:
#           neighbourhood_group    neighbourhood        room_type  price  \
# 3      Tempelhof - Schöneberg  Schöneberg-Nord     Private room     26
# 28     Tempelhof - Schöneberg  Schöneberg-Nord     Private room     25
# 64     Tempelhof - Schöneberg  Schöneberg-Nord  Entire home/apt     69
# 81     Tempelhof - Schöneberg  Schöneberg-Nord  Entire home/apt     80
# 84     Tempelhof - Schöneberg   Schöneberg-Süd  Entire home/apt    130
# ...                       ...              ...              ...    ...
# 22265  Tempelhof - Schöneberg  Schöneberg-Nord     Private room     32
# 22267  Tempelhof - Schöneberg        Friedenau     Private room     50
# 22283  Tempelhof - Schöneberg        Tempelhof     Private room     22
# 22300  Tempelhof - Schöneberg  Schöneberg-Nord     Private room     27
# 22309  Tempelhof - Schöneberg        Friedenau     Private room     22
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 3                   5                 25               0.39
# 28                  5                 21               0.21
# 64                  3                200               2.14
# 81                  3                 59               0.66
# 84                  3                 53               0.74
# ...               ...                ...                ...
# 22265               2                  3               3.00
# 22267               1                  1               1.00
# 22283               1                  1               1.00
# 22300               1                  2               2.00
# 22309               2                  1               1.00
#
#        calculated_host_listings_count  availability_365
# 3                                   1               297
# 28                                  1               329
# 64                                  1               178
# 81                                  1               363
# 84                                  1               140
# ...                               ...               ...
# 22265                               6                23
# 22267                               1               213
# 22283                               1               264
# 22300                               2                 9
# 22309                               1                 9
#
# [1275 rows x 9 columns]

# %%
X = clusteringDataset.iloc[:, [3, 4]].values
# atrA = MinMaxScaler().fit_transform(X[:,[0]])
# atrB = MinMaxScaler().fit_transform(X[:,[1]])
atrA = (X[:,[0]])
atrB = (X[:,[1]])
datanya = []
for i in range (len(atrA)):
    datanya.append([float(atrA[i]),float(atrB[i])])

# %%
mX = squareform(pdist(datanya))
# mX = squareform(X)
# print(mX)

# %%
#Inisiasi Cluster Awal
clusters = []
for i in range(len(X)):
    clusters.append([i])
# clusters
pCluster = len(X)
#nilai Cluster dapat dibuah disini
jumlahCluster = 3
while pCluster != jumlahCluster:
    close = []
    y, z = np.where( mX==np.min(mX[np.nonzero(mX)]))
    close.extend([y[-1],z[-1]])
    mustMerge = close
    #Mencari titik dari nilai terkecil pada distance matriks

    mergeClusters = []
#     print(mustMerge)
    mergeClusters.extend(clusters.pop(mustMerge[0]))
    mergeClusters.extend(clusters.pop(mustMerge[1]))                           
    clusters.append(mergeClusters)

    #Menyatukan Cluster Berdasarkan Titik

    A = mX[mustMerge[0]]
    A = np.delete(A, [mustMerge[0]], 0)
    A = np.delete(A, [mustMerge[1]], 0)
    B = mX[mustMerge[1]]
    B = np.delete(B, [mustMerge[0]], 0)
    B = np.delete(B, [mustMerge[1]], 0)
    insertThis = []
    temp = 0
    for i in range(len(A)):
    #       Start of Single Linkage
#         if A[i] <= B[i]:
#             insertThis = np.insert(insertThis, i, A[i])
#         else:
#             insertThis = np.insert(insertThis, i, B[i])
#         temp = i + 1
    #       End of Comlete Linkage

    #       Start of Comlete Linkage
            if A[i] >= B[i]:
                insertThis = np.insert(insertThis, i, A[i])
            else:
                insertThis = np.insert(insertThis, i, B[i])
            temp = i + 1
    #       End of Comlete Linkage

    #       Start of Average Linkage
#             insertThis = np.insert(insertThis,i, (A[i]+B[i])/2)
#             temp = i + 1
    #       End of Average Linkage

    insertThis = np.insert(insertThis, temp, 0)

    #Mencari nilai yang akan dimasukan ke distance Matrix

    mX = (np.delete(np.delete(mX, mustMerge[0], 0), mustMerge[0], 1))
    mX = (np.delete(np.delete(mX, mustMerge[1], 0), mustMerge[1], 1))

    #Delete distance matriks pada titik nilai minimal

    bMX = mX.copy()
    bMX = np.zeros((len(mX)+1,len(mX)+1))
    bMX[:-1,:-1] = mX
    bMX = np.insert(bMX,len(bMX)-1, insertThis, 0)
    bMX = np.delete(bMX, len(bMX)-1, axis = 0)
    bMX = np.insert(bMX,len(bMX)-1, insertThis, 1)
    bMX = np.delete(bMX, len(bMX), axis = 1)
    mX = bMX
#     print("iteration: ", pCluster)
    pCluster -= 1
    #Nilai distance matriks baru

# %%
figure(figsize=(10,10))
plt.scatter(X[clusters[0],[0]], X[clusters[0],[1]], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[clusters[1],[0]], X[clusters[1],[1]], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X[clusters[2],[0]], X[clusters[2],[1]], s = 100, c = 'green', label = 'Cluster 3')
# plt.scatter(X[clusters[3],[0]], X[clusters[3],[1]], s = 100, c = 'cyan', label = 'Cluster 4')
# plt.scatter(X[clusters[4],[0]], X[clusters[4],[1]], s = 100, c = 'magenta', label = 'Cluster 5')
# plt.scatter(X[clusters[5],[0]], X[clusters[5],[1]], s = 100, c = 'gray', label = 'Cluster 6')
# plt.scatter(X[clusters[6],[0]], X[clusters[6],[1]], s = 100, c = 'brown', label = 'Cluster 7')
plt.title('Clusters of customers in Tempelhof - Schöneberg')
plt.xlabel('Price')
plt.ylabel('Minimum Night')
plt.legend()
plt.show()

# %%
label = np.zeros(len(X))
for i in range(len(clusters)):
    label[clusters[i]] = i
print("Calinski-Harabasz", metrics.calinski_harabasz_score(X, label))
print("Silhouette Coefficient", metrics.silhouette_score(X, label, metric='euclidean'))
# Out:
# Calinski-Harabasz 1003.4289362034199
# Silhouette Coefficient 0.6691083381247709

# %%
clusteringDataset = dataset.copy()
clusteringDataset = clusteringDataset.drop(['id', 'name', 'host_id', 'host_name' ,'latitude','longitude','last_review'], axis = 1)
print(Counter(clusteringDataset["neighbourhood_group"]))
# Out:
# Counter({'Friedrichshain-Kreuzberg': 4570, 'Mitte': 3791, 'Pankow': 2935, 'Neukölln': 2892, 'Tempelhof - Schöneberg': 1275, 'Charlottenburg-Wilm.': 1267, 'Lichtenberg': 526, 'Treptow - Köpenick': 475, 'Steglitz - Zehlendorf': 350, 'Reinickendorf': 199, 'Marzahn - Hellersdorf': 114, 'Spandau': 94})

# %%
idxNeigh = clusteringDataset[clusteringDataset['neighbourhood_group'] != "Neukölln"].index.tolist()
clusteringDataset.drop(idxNeigh, inplace = True)
clusteringDataset
# Out:
#       neighbourhood_group             neighbourhood        room_type  price  \
# 10               Neukölln              Reuterstraße  Entire home/apt     49
# 21               Neukölln              Reuterstraße  Entire home/apt     60
# 32               Neukölln         Schillerpromenade  Entire home/apt     80
# 57               Neukölln  Neuköllner Mitte/Zentrum     Private room     37
# 77               Neukölln              Reuterstraße  Entire home/apt     60
# ...                   ...                       ...              ...    ...
# 22191            Neukölln         Schillerpromenade     Private room     34
# 22233            Neukölln                   Rixdorf     Private room     22
# 22235            Neukölln                   Rixdorf     Private room     30
# 22247            Neukölln              Reuterstraße  Entire home/apt     44
# 22268            Neukölln         Schillerpromenade  Entire home/apt     50
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 10                  5                223               2.10
# 21                  2                  1               0.02
# 32                 10                  6               0.06
# 57                  6                 96               1.28
# 77                  2                 44               0.48
# ...               ...                ...                ...
# 22191               1                  1               1.00
# 22233               3                  1               1.00
# 22235               2                  2               2.00
# 22247               1                  2               2.00
# 22268               7                  1               1.00
#
#        calculated_host_listings_count  availability_365
# 10                                  1               232
# 21                                 10               341
# 32                                  1               310
# 57                                  2               347
# 77                                  1                 2
# ...                               ...               ...
# 22191                               1                12
# 22233                               1                 4
# 22235                               1                58
# 22247                               1                 6
# 22268                               1                 8
#
# [2892 rows x 9 columns]

# %%
X = clusteringDataset.iloc[:, [3, 4]].values
# atrA = MinMaxScaler().fit_transform(X[:,[0]])
# atrB = MinMaxScaler().fit_transform(X[:,[1]])
atrA = (X[:,[0]])
atrB = (X[:,[1]])
datanya = []
for i in range (len(atrA)):
    datanya.append([float(atrA[i]),float(atrB[i])])
mX = squareform(pdist(datanya))

# %%
#Inisiasi Cluster Awal
clusters = []
for i in range(len(X)):
    clusters.append([i])
# clusters
pCluster = len(X)
#nilai Cluster dapat dibuah disini
jumlahCluster = 3
while pCluster != jumlahCluster:
    close = []
    y, z = np.where( mX==np.min(mX[np.nonzero(mX)]))
    close.extend([y[-1],z[-1]])
    mustMerge = close
    #Mencari titik dari nilai terkecil pada distance matriks

    mergeClusters = []
#     print(mustMerge)
    mergeClusters.extend(clusters.pop(mustMerge[0]))
    mergeClusters.extend(clusters.pop(mustMerge[1]))                           
    clusters.append(mergeClusters)

    #Menyatukan Cluster Berdasarkan Titik

    A = mX[mustMerge[0]]
    A = np.delete(A, [mustMerge[0]], 0)
    A = np.delete(A, [mustMerge[1]], 0)
    B = mX[mustMerge[1]]
    B = np.delete(B, [mustMerge[0]], 0)
    B = np.delete(B, [mustMerge[1]], 0)
    insertThis = []
    temp = 0
    for i in range(len(A)):
    #       Start of Single Linkage
#         if A[i] <= B[i]:
#             insertThis = np.insert(insertThis, i, A[i])
#         else:
#             insertThis = np.insert(insertThis, i, B[i])
#         temp = i + 1
    #       End of Comlete Linkage

    #       Start of Comlete Linkage
            if A[i] >= B[i]:
                insertThis = np.insert(insertThis, i, A[i])
            else:
                insertThis = np.insert(insertThis, i, B[i])
            temp = i + 1
    #       End of Comlete Linkage

    #       Start of Average Linkage
#             insertThis = np.insert(insertThis,i, (A[i]+B[i])/2)
#             temp = i + 1
    #       End of Average Linkage

    insertThis = np.insert(insertThis, temp, 0)

    #Mencari nilai yang akan dimasukan ke distance Matrix

    mX = (np.delete(np.delete(mX, mustMerge[0], 0), mustMerge[0], 1))
    mX = (np.delete(np.delete(mX, mustMerge[1], 0), mustMerge[1], 1))

    #Delete distance matriks pada titik nilai minimal

    bMX = mX.copy()
    bMX = np.zeros((len(mX)+1,len(mX)+1))
    bMX[:-1,:-1] = mX
    bMX = np.insert(bMX,len(bMX)-1, insertThis, 0)
    bMX = np.delete(bMX, len(bMX)-1, axis = 0)
    bMX = np.insert(bMX,len(bMX)-1, insertThis, 1)
    bMX = np.delete(bMX, len(bMX), axis = 1)
    mX = bMX
#     print("iteration: ", pCluster)
    pCluster -= 1
    #Nilai distance matriks baru

# %%
figure(figsize=(10,10))
plt.scatter(X[clusters[0],[0]], X[clusters[0],[1]], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[clusters[1],[0]], X[clusters[1],[1]], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X[clusters[2],[0]], X[clusters[2],[1]], s = 100, c = 'green', label = 'Cluster 3')
# plt.scatter(X[clusters[3],[0]], X[clusters[3],[1]], s = 100, c = 'cyan', label = 'Cluster 4')
# plt.scatter(X[clusters[4],[0]], X[clusters[4],[1]], s = 100, c = 'magenta', label = 'Cluster 5')
# plt.scatter(X[clusters[5],[0]], X[clusters[5],[1]], s = 100, c = 'gray', label = 'Cluster 6')
# plt.scatter(X[clusters[6],[0]], X[clusters[6],[1]], s = 100, c = 'brown', label = 'Cluster 7')
plt.title('Clusters of customers in Neukölln')
plt.xlabel('Price')
plt.ylabel('Minimum Night')
plt.legend()
plt.show()

# %%
label = np.zeros(len(X))
for i in range(len(clusters)):
    label[clusters[i]] = i
print("Calinski-Harabasz", metrics.calinski_harabasz_score(X, label))
print("Silhouette Coefficient", metrics.silhouette_score(X, label, metric='euclidean'))
# Out:
# Calinski-Harabasz 982.6548559570152
# Silhouette Coefficient 0.905604568366408

# %%
converttoCSV = dataset.copy()
converttoCSV = converttoCSV.drop(['id', 'name', 'host_id', 'host_name' ,'latitude','longitude','last_review'], axis = 1)
converttoCSV.to_csv('air_bnb_case2.csv')
#export bentuk CSV hasil preprocessing
